# %%
import pandas as pd
import matplotlib.pyplot as plt

csv_file = "../data/kvadrati2/kvadrati.csv"
kvadrati_df = pd.read_csv(csv_file, encoding="utf-8")
kvadrati_df.head()
# Out:
#    id                                          naslov   latitude  longitude  \
# 0   1  Notranjsko - kraška, Ilirska Bistrica, Hrušica  45.846179  14.230267
# 1   2                         Pomurska, Murska Sobota  46.662464  16.165526
# 2   3                 Podravska, Destrnik, Vintarovci  46.495602  15.864561
# 3   4                  Goriška, Kanal ob Soči, Doblar  46.115738  13.687290
# 4   5                       Podravska, Maribor, Pekre  46.543337  15.592553
#
#   vrsta_prodaje    vrsta              tip  velikost  leto_gradnje       cena  \
# 0       Prodaja  Parcela       Zazidljiva   4194 m2           NaN   37.000 €
# 1       Prodaja  Parcela       Zazidljiva   1898 m2           NaN    40 €/m2
# 2       Prodaja  Parcela       Zazidljiva    646 m2           NaN   23.500 €
# 3       Prodaja     Hiša       Samostojna  223.6 m2        1924.0  110.000 €
# 4       Prodaja     Hiša  Večstanovanjska  322.6 m2        1973.0  579.000 €
#
#   prodajalec_oseba        prodajalec_agencija  \
# 0      Nina Hudnik   RONI NEPREMIČNINE d.o.o.
# 1   Rajko  Šimonka  Prips nepremičnine d.o.o.
# 2   Melanija Raišp       CENTURY 21 Slovenija
# 3       Jure Repše               RENES d.o.o.
# 4  Barbara Pečenik       BAZA AGENCIJA d.o.o.
#
#                                              splosno  \
# 0                              Šifra:=PP397815031525
# 1                                    Šifra:=P26-2022
# 2                                  Šifra:=100104-589
# 3  Parcela:=17967 m2|Zgrajeno:=1924|Ener. izk.=G|...
# 4  Velikost (bruto):=322.6 m2|Parcela:=535 m2|Št....
#
#                                          znacilnosti  \
# 0                                                NaN
# 1                                                NaN
# 2  Lega=Jug/Zahod|Luksuz=Lep razgled/Bližina nara...
# 3                        Dodatno=Balkon/Atrij/Terasa
# 4  Ogrevanje=Toplotna črpalka|Luksuz=Klima/Lep ra...
#
#                                                 opis  \
# 0  Iščete primerno zemljišče za gradnjo ali inves...
# 1  Nedaleč od trgovskega središča prodamo zemljiš...
# 2  ZEMLJIŠČE V VINTAROVCIH, DESTRNIKProdamo zemlj...
# 3  DOBLARSamostojna stanovanjska hiša velikosti 2...
# 4  Na odlični in mirni lokaciji v Pekrah prodamo ...
#
#                                                  url
# 0  https://mojikvadrati.com/nepremicnina/467410-p...
# 1  https://mojikvadrati.com/nepremicnina/373458-p...
# 2  https://mojikvadrati.com/nepremicnina/453310-p...
# 3  https://mojikvadrati.com/nepremicnina/424445-p...
# 4  https://mojikvadrati.com/nepremicnina/469054-p...

# %% [markdown]
# Histogram starosti nepremicnin:

# %%
kvadrati_gradnje_df = kvadrati_df[kvadrati_df['leto_gradnje'].notnull()]
leto_gradnje = kvadrati_gradnje_df[kvadrati_gradnje_df['leto_gradnje'] > 1000]['leto_gradnje']

plt.figure(figsize=(10, 6))
plt.hist(leto_gradnje, bins="sqrt", color='skyblue', edgecolor='black')
plt.title('Histogram let gradnje nepremičnin')
plt.xlabel('Leto gradnje')
plt.ylabel('Število nepremičnin')
plt.grid(True)
plt.show()

# %%
kvadrati_gradnje_df.sort_values("leto_gradnje").head(10)
# Out:
#         id                                      naslov   latitude  longitude  \
# 4598  4603                       Ljubljana, Vič-Rudnik  46.046481  14.487010
# 1002  1004                      Goriška, Brda, Biljana  45.997206  13.534751
# 443    444                         Hrvaška, Bale, BALE  45.041053  13.786641
# 1180  1182                  Savinjska, Kozje, Podsreda  46.040177  15.590055
# 3734  3737                        Podravska, Oplotnica  46.386693  15.448631
# 5926  5936  Jugovzhodna Slovenija, Šentjernej, Hrastje  45.978236  16.268864
# 6448  6463  Jugovzhodna Slovenija, Šentjernej, Hrastje  45.978236  16.268864
# 6222  6234                                      Tujina        NaN        NaN
# 2958  2960                      Obalno - kraška, Piran  45.528492  13.568449
# 727    729                      Obalno - kraška, Piran  45.528492  13.568449
#
#      vrsta_prodaje             vrsta                 tip velikost  \
# 4598       Prodaja           Parcela          Zazidljiva  2445 m2
# 1002       Prodaja           Parcela  Kmetijska površina  7401 m2
# 443        Prodaja              Hiša          Samostojna   260 m2
# 1180       Prodaja              Hiša          Samostojna   120 m2
# 3734       Prodaja              Hiša          Samostojna   250 m2
# 5926       Prodaja  Poslovni prostor         Grad/dvorec  2229 m2
# 6448       Prodaja              Hiša          Samostojna  2229 m2
# 6222       Prodaja              Hiša          Samostojna   390 m2
# 2958       Prodaja        Stanovanje             1-sobno    33 m2
# 727        Prodaja        Stanovanje             3-sobno    66 m2
#
#       leto_gradnje         cena     prodajalec_oseba  \
# 4598           1.0  1.950.000 €         Janez Dragar
# 1002           1.0     21.462 €      Zdenko Peršolja
# 443         1100.0    550.000 €       Anja Novaković
# 1180        1270.0     59.800 €        Karmen Tertei
# 3734        1300.0    420.000 €       Melanija Raišp
# 5926        1360.0  1.150.000 €         Anja Ščukovt
# 6448        1360.0  1.150.000 €         Anja Ščukovt
# 6222        1374.0  3.500.000 €  URBANISTIKA, d.o.o.
# 2958        1380.0    223.000 €         Suzana Legen
# 727         1380.0    280.000 €         Suzana Legen
#
#                                     prodajalec_agencija  \
# 4598                                Stoja trade, d.o.o.
# 1002                                Stoja trade, d.o.o.
# 443                                     Eurogeld d.o.o.
# 1180                                   ABC nepremičnine
# 3734                               CENTURY 21 Slovenija
# 5926                              AGENCIJA ELITE d.o.o.
# 6448                              AGENCIJA ELITE d.o.o.
# 6222                                 Urbanistika d.o.o.
# 2958  Piran nepremičnine, Oglaševanje, Suzana Legen ...
# 727   Piran nepremičnine, Oglaševanje, Suzana Legen ...
#
#                                                 splosno  \
# 4598  Zgrajeno:=1|Ener. izk.=Ni podatka|Šifra:=PZ225...
# 1002  Zgrajeno:=1|Ener. izk.=Ni podatka|Šifra:=PZ255...
# 443   Velikost (bruto):=260 m2|Parcela:=60 m2|Zgraje...
# 1180  Velikost (bruto):=120 m2|Parcela:=55948 m2|Zgr...
# 3734  Velikost (bruto):=250 m2|Parcela:=7222 m2|Št. ...
# 5926  Velikost (bruto):=2229 m2|Parcela:=119990 m2|Z...
# 6448  Velikost (bruto):=2229 m2|Parcela:=119990 m2|Z...
# 6222  Velikost (bruto):=390 m2|Parcela:=594 m2|Zgraj...
# 2958    Nadstropje:=2/3|Zgrajeno:=1380|Adaptacija:=1990
# 727   Nadstropje:=1/3|Zgrajeno:=1380|Adaptacija:=199...
#
#                                             znacilnosti  \
# 4598                                                NaN
# 1002                                                NaN
# 443                                                 NaN
# 1180                                                NaN
# 3734  Priključki=Greznica|Ogrevanje=Elektrika/Drva|L...
# 5926                                                NaN
# 6448                                                NaN
# 6222                                                NaN
# 2958                                                NaN
# 727                                                 NaN
#
#                                                    opis  \
# 4598  Na Rudniku prodamo parcelo ob Dolenjski cesti ...
# 1002  V Goriških brdih na lepi, sončni in dostopni l...
# 443   BALEProdaja se hiša v staromestnem jedru  prel...
# 1180  PODSREDAKozjansko - Podsreda - Srednjeveška hi...
# 3734  RESTAVRIRANA POHORSKA HIŠARESTAVRIRANA POHORSK...
# 5926  GRAD GRACARJEV TURNGrad Gracarjev Turn – Zgodo...
# 6448  GRAD GRACARJEV TURNGrad Gracarjev Turn – Zgodo...
# 6222  ITALIJA, TRIESTE, SOPOTGRAD MUGGIA IZ 14. STOL...
# 2958  PIRANV 2.nadstropju tristanovanjske stavbe pro...
# 727   3 garsonjere3 enoteV 1.nadstropju in pritličju...
#
#                                                     url
# 4598  https://mojikvadrati.com/nepremicnina/391866-p...
# 1002  https://mojikvadrati.com/nepremicnina/394057-p...
# 443   https://mojikvadrati.com/nepremicnina/429532-p...
# 1180  https://mojikvadrati.com/nepremicnina/469790-p...
# 3734  https://mojikvadrati.com/nepremicnina/472286-p...
# 5926  https://mojikvadrati.com/nepremicnina/468036-p...
# 6448  https://mojikvadrati.com/nepremicnina/467909-p...
# 6222  https://mojikvadrati.com/nepremicnina/469435-p...
# 2958  https://mojikvadrati.com/nepremicnina/431495-p...
# 727   https://mojikvadrati.com/nepremicnina/431497-p...

# %% [markdown]
# Parcele z letom 1 ignoriraj. Veliko starih hiš
#
# <img src="images/image.png" alt="drawing" height="200"/>
# <img src="images/image2.png" alt="drawing" height="200"/>

# %% [markdown]
# Samo od 1900 naprej:

# %%
leto_gradnje = kvadrati_gradnje_df[kvadrati_gradnje_df['leto_gradnje'] >= 1900]['leto_gradnje'].dropna()

plt.figure(figsize=(10, 6))
plt.hist(leto_gradnje, bins="sqrt", color='skyblue', edgecolor='black')
plt.title('Histogram let gradnje nepremičnin')
plt.xlabel('Leto gradnje')
plt.ylabel('Število nepremičnin')
plt.grid(True)
plt.show()

# %% [markdown]
# Od 2000 naprej:

# %%
leto_gradnje = kvadrati_gradnje_df[kvadrati_gradnje_df['leto_gradnje'] > 2000]['leto_gradnje'].astype(int).dropna()

plt.figure(figsize=(10, 6))
plt.hist(leto_gradnje, bins="sqrt", color='skyblue', edgecolor='black')
plt.title('Histogram let gradnje nepremičnin')
plt.xlabel('Leto gradnje')
plt.ylabel('Število nepremičnin')
plt.grid(True)
plt.show()

# %%
leto_gradnje = kvadrati_gradnje_df[kvadrati_gradnje_df['leto_gradnje'] > 2020]['leto_gradnje'].astype(int).dropna()

plt.figure(figsize=(10, 6))
plt.hist(leto_gradnje, bins="sqrt", color='skyblue', edgecolor='black')
plt.title('Histogram let gradnje nepremičnin')
plt.xlabel('Leto gradnje')
plt.ylabel('Število nepremičnin')
plt.grid(True)
plt.show()

# %%
kvadrati_gradnje_df.sort_values("leto_gradnje", ascending=False).head(10)
# Out:
#         id                               naslov   latitude  longitude  \
# 6184  6196  Ljubljana, Vič-Rudnik, Rožna dolina  45.942269  13.646351
# 1579  1581                 Goriška, Nova Gorica  45.958055  13.647471
# 4175  4180                 Goriška, Nova Gorica  45.958055  13.647471
# 4652  4657  Ljubljana, Vič-Rudnik, Rožna dolina  45.942269  13.646351
# 2298  2300  Ljubljana, Vič-Rudnik, Rožna dolina  45.942269  13.646351
# 6071  6083                 Goriška, Nova Gorica  45.958055  13.647471
# 4939  4946  Ljubljana, Vič-Rudnik, Rožna dolina  45.942269  13.646351
# 1119  1121  Ljubljana, Vič-Rudnik, Rožna dolina  45.942269  13.646351
# 675    677                 Goriška, Nova Gorica  45.958055  13.647471
# 801    803  Ljubljana, Vič-Rudnik, Rožna dolina  45.942269  13.646351
#
#      vrsta_prodaje       vrsta        tip   velikost  leto_gradnje  \
# 6184       Prodaja  Stanovanje    4-sobno  117.15 m2        2027.0
# 1579       Prodaja  Stanovanje  3,5-sobno   80.54 m2        2027.0
# 4175       Prodaja  Stanovanje  2,5-sobno   67.47 m2        2027.0
# 4652       Prodaja  Stanovanje    4-sobno  117.06 m2        2027.0
# 2298       Prodaja  Stanovanje    4-sobno  354.27 m2        2027.0
# 6071       Prodaja  Stanovanje  3,5-sobno   77.24 m2        2027.0
# 4939       Prodaja  Stanovanje    4-sobno  113.39 m2        2027.0
# 1119       Prodaja  Stanovanje    4-sobno  132.23 m2        2027.0
# 675        Prodaja  Stanovanje    2-sobno    62.7 m2        2027.0
# 801        Prodaja  Stanovanje    4-sobno  455.97 m2        2027.0
#
#              cena prodajalec_oseba     prodajalec_agencija  \
# 6184  1.034.565 €      Sara Jamnik  Ljubljana nepremicnine
# 1579    353.423 €      Zoran Đukić     Stoja trade, d.o.o.
# 4175    291.150 €      Zoran Đukić     Stoja trade, d.o.o.
# 4652    985.268 €      Sara Jamnik  Ljubljana nepremicnine
# 2298    963.966 €      Sara Jamnik  Ljubljana nepremicnine
# 6071    340.745 €      Zoran Đukić     Stoja trade, d.o.o.
# 4939  1.012.024 €      Sara Jamnik  Ljubljana nepremicnine
# 1119  1.291.723 €      Sara Jamnik  Ljubljana nepremicnine
# 675     281.890 €      Zoran Đukić     Stoja trade, d.o.o.
# 801   1.473.178 €      Sara Jamnik  Ljubljana nepremicnine
#
#                                                 splosno  \
# 6184  Velikost (bruto):=117.15 m2|Nadstropje:=2/2|Št...
# 1579  Velikost (bruto):=80.54 m2|Nadstropje:=6/7|Št....
# 4175  Velikost (neto):=57.65 m2|Velikost (bruto):=67...
# 4652  Velikost (bruto):=117.06 m2|Nadstropje:=1/2|Št...
# 2298  Velikost (bruto):=354.27 m2|Nadstropje:=Pritli...
# 6071  Velikost (bruto):=77.24 m2|Nadstropje:=7/7|Št....
# 4939  Velikost (bruto):=113.39 m2|Nadstropje:=2/2|Št...
# 1119  Velikost (bruto):=132.23 m2|Nadstropje:=2/2|Št...
# 675   Velikost (neto):=52.98 m2|Velikost (bruto):=62...
# 801   Velikost (bruto):=455.97 m2|Nadstropje:=Pritli...
#
#                                             znacilnosti  \
# 6184  Priključki=Optika|Ogrevanje=Plin|Lega=Vzhod/Ju...
# 1579                                                NaN
# 4175                                                NaN
# 4652  Priključki=Optika|Ogrevanje=Plin|Lega=Vzhod/Ju...
# 2298  Priključki=Optika|Ogrevanje=Plin|Lega=Vzhod|Lu...
# 6071                                                NaN
# 4939  Priključki=Optika|Ogrevanje=Plin|Lega=Jug|Luks...
# 1119  Priključki=Optika|Ogrevanje=Plin|Lega=Zahod|Lu...
# 675                                                 NaN
# 801   Priključki=Optika|Ogrevanje=Plin|Lega=Vzhod|Lu...
#
#                                                    opis  \
# 6184  REZIDENCA ROŽNA DOLINA - 4 sobno stanovanje z ...
# 1579  Predstavljamo vam moderno 3,5-sobno stanovanje...
# 4175  Na prodaj je privlačno 2,5-sobno stanovanje, k...
# 4652  REZIDENCA ROŽNA DOLINA - 4 sobno stanovanje z ...
# 2298  REZIDENCA ROŽNA DOLINA - 4 sobno stanovanjeV r...
# 6071  Predstavljamo vam čudovito priložnost za nakup...
# 4939  REZIDENCA ROŽNA DOLINA - 4 sobno stanovanjeV r...
# 1119  REZIDENCA ROŽNA DOLINA - 4 sobno stanovanjeV r...
# 675   Predstavljamo vam moderno in prostorno 2-sobno...
# 801   REZIDENCA ROŽNA DOLINA - 4 sobno stanovanjeV r...
#
#                                                     url
# 6184  https://mojikvadrati.com/nepremicnina/476697-p...
# 1579  https://mojikvadrati.com/nepremicnina/479221-p...
# 4175  https://mojikvadrati.com/nepremicnina/479227-p...
# 4652  https://mojikvadrati.com/nepremicnina/476465-p...
# 2298  https://mojikvadrati.com/nepremicnina/476343-p...
# 6071  https://mojikvadrati.com/nepremicnina/479115-p...
# 4939  https://mojikvadrati.com/nepremicnina/476776-p...
# 1119  https://mojikvadrati.com/nepremicnina/476487-p...
# 675   https://mojikvadrati.com/nepremicnina/479225-p...
# 801   https://mojikvadrati.com/nepremicnina/476353-p...

# %% [markdown]
# Veliko hiš, ki še niso zgrajene. Največ novogradenj - 22%.

# %%
len(kvadrati_gradnje_df[kvadrati_gradnje_df['leto_gradnje'] >= 2024]) / len(kvadrati_gradnje_df)
# Out:
# 0.21750296325563018

# %%
len(kvadrati_gradnje_df[(kvadrati_gradnje_df['leto_gradnje'] >= 2024) & (kvadrati_gradnje_df["prodajalec_agencija"] == "Ljubljana nepremicnine")]) / len(kvadrati_gradnje_df[kvadrati_gradnje_df['leto_gradnje'] >= 2024])
# Out:
# 0.11898274296094459

# %% [markdown]
# Ljubljana nepremičnine prodaja 12% vseh novogradenj.

# %%
len(kvadrati_gradnje_df[(kvadrati_gradnje_df['leto_gradnje'] >= 2024) & (kvadrati_gradnje_df["prodajalec_agencija"] == "CENTURY 21 Slovenija")]) / len(kvadrati_gradnje_df[kvadrati_gradnje_df['leto_gradnje'] >= 2024])
# Out:
# 0.12352406902815623

# %% [markdown]
# CENTURY 21 isto 12%

# %% [markdown]
# Če probamo fittat distribucije, dobimo to:

# %%
from distfit import distfit

leto_gradnje = kvadrati_gradnje_df[kvadrati_gradnje_df['leto_gradnje'] >= 2020]['leto_gradnje'].astype(int).dropna()
dist = distfit()
dist.fit_transform(leto_gradnje)
# Out:
# 12-04-25 21:56:57 [distfit.distfit] > INFO     > fit
# 12-04-25 21:56:57 [distfit.distfit] > INFO     > transform
# 12-04-25 21:56:57 [distfit.distfit] > INFO     > [norm      ] [0.00 sec] [RSS: 7.6682] [loc=2024.062 scale=1.216]
# 12-04-25 21:56:57 [distfit.distfit] > INFO     > [expon     ] [0.00 sec] [RSS: 8.76875] [loc=2020.000 scale=4.062]
# 12-04-25 21:56:57 [distfit.distfit] > INFO     > [pareto    ] [0.00 sec] [RSS: 8.76875] [loc=-1073739804.000 scale=1073741824.000]
# 12-04-25 21:56:57 [distfit.distfit] > INFO     > [dweibull  ] [0.02 sec] [RSS: 6.08915] [loc=2024.000 scale=0.690]
# 12-04-25 21:56:57 [distfit.distfit] > INFO     > [t         ] [0.05 sec] [RSS: 7.6682] [loc=2024.062 scale=1.216]
# 12-04-25 21:56:57 [distfit.distfit] > INFO     > [genextreme] [0.01 sec] [RSS: 7.71066] [loc=2023.676 scale=1.321]
# 12-04-25 21:56:57 [distfit.distfit] > INFO     > [gamma     ] [0.01 sec] [RSS: 7.69424] [loc=2001.417 scale=0.070]
# 12-04-25 21:56:57 [distfit.distfit] > INFO     > [lognorm   ] [0.00 sec] [RSS: 7.66821] [loc=-129052.000 scale=131076.062]
# 12-04-25 21:56:57 [distfit.distfit] > INFO     > [beta      ] [0.01 sec] [RSS: 9.17886] [loc=2959.725 scale=0.000]
# 12-04-25 21:56:57 [distfit.distfit] > INFO     > [uniform   ] [0.00 sec] [RSS: 8.36254] [loc=2020.000 scale=7.000]
# 12-04-25 21:56:57 [distfit.distfit] > INFO     > [loggamma  ] [0.00 sec] [RSS: 7.63869] [loc=2022.204 scale=1.938]
# 12-04-25 21:56:57 [distfit.distfit] > INFO     > [norm      ] [0.14 sec] [RSS: 7.6682] [loc=2024.062 scale=1.216]
# 12-04-25 21:56:57 [distfit.distfit] > INFO     > [expon     ] [0.14 sec] [RSS: 8.76875] [loc=2020.000 scale=4.062]
# 12-04-25 21:56:57 [distfit.distfit] > INFO     > [pareto    ] [0.14 sec] [RSS: 8.76875] [loc=-1073739804.000 scale=1073741824.000]
# 12-04-25 21:56:57 [distfit.distfit] > INFO     > [dweibull  ] [0.14 sec] [RSS: 6.08915] [loc=2024.000 scale=0.690]
# 12-04-25 21:56:57 [distfit.distfit] > INFO     > [t         ] [0.11 sec] [RSS: 7.6682] [loc=2024.062 scale=1.216]
# 12-04-25 21:56:57 [distfit.distfit] > INFO     > [genextreme] [0.06 sec] [RSS: 7.71066] [loc=2023.676 scale=1.321]
# 12-04-25 21:56:57 [distfit.distfit] > INFO     > [gamma     ] [0.04 sec] [RSS: 7.69424] [loc=2001.417 scale=0.070]
# 12-04-25 21:56:57 [distfit.distfit] > INFO     > [lognorm   ] [0.02 sec] [RSS: 7.66821] [loc=-129052.000 scale=131076.062]
# 12-04-25 21:56:57 [distfit.distfit] > INFO     > [beta      ] [0.02 sec] [RSS: 9.17886] [loc=2959.725 scale=0.000]
# 12-04-25 21:56:57 [distfit.distfit] > INFO     > [uniform   ] [0.00 sec] [RSS: 8.36254] [loc=2020.000 scale=7.000]
# 12-04-25 21:56:57 [distfit.distfit] > INFO     > [loggamma  ] [0.00 sec] [RSS: 7.63869] [loc=2022.204 scale=1.938]
# 12-04-25 21:56:57 [distfit.distfit] > INFO     > Compute confidence intervals [parametric]
# {'model': {'name': 'dweibull',
#   'score': 6.08914889486159,
#   'loc': 2024.0000000000005,
#   'scale': 0.6897624994832385,
#   'arg': (np.float64(0.5184183310191961),),
#   'params': (np.float64(0.5184183310191961),
#    np.float64(2024.0000000000005),
#    np.float64(0.6897624994832385)),
#   'model': <scipy.stats._distn_infrastructure.rv_continuous_frozen at 0x112f42030>,
#   'bootstrap_score': 0,
#   'bootstrap_pass': None,
#   'color': '#e41a1c',
#   'CII_min_alpha': np.float64(2020.5533799649947),
#   'CII_max_alpha': np.float64(2027.4466200350062)},
#  'summary':           name     score           loc          scale  \
#  0     dweibull  6.089149        2024.0       0.689762
#  1     loggamma  7.638693   2022.204141       1.937782
#  2            t  7.668198   2024.061627       1.215721
#  3         norm  7.668201   2024.061625       1.215728
#  4      lognorm  7.668205     -129052.0  131076.061619
#  5        gamma  7.694241   2001.416871       0.069607
#  6   genextreme  7.710663   2023.676394       1.320603
#  7      uniform  8.362535        2020.0            7.0
#  8       pareto  8.768752 -1073739804.0   1073741824.0
#  9        expon  8.768752        2020.0       4.061625
#  10        beta  9.178862   2959.725416            0.0
#
#                                           arg  \
#  0                      (0.5184183310191961,)
#  1                        (3.09221291748985,)
#  2                      (330060.07700035756,)
#  3                                         ()
#  4                   (9.275021836847712e-06,)
#  5                       (325.1160321634661,)
#  6                      (0.3660352945632158,)
#  7                                         ()
#  8                      (264362642.72962403,)
#  9                                         ()
#  10  (2507541.2770303385, 3.9971245398269533)
#
#                                                 params  \
#  0   (0.5184183310191961, 2024.0000000000005, 0.689...
#  1   (3.09221291748985, 2022.2041409643957, 1.93778...
#  2   (330060.07700035756, 2024.0616272703182, 1.215...
#  3               (2024.06162464986, 1.215728226050738)
#  4   (9.275021836847712e-06, -129051.99999999984, 1...
#  5   (325.1160321634661, 2001.4168713709437, 0.0696...
#  6   (0.3660352945632158, 2023.6763944106349, 1.320...
#  7                                       (2020.0, 7.0)
#  8   (264362642.72962403, -1073739804.0, 1073741823...
#  9                          (2020.0, 4.06162464986005)
#  10  (2507541.2770303385, 3.9971245398269533, 2959....
#
#                                                  model bootstrap_score  \
#  0   <scipy.stats._distn_infrastructure.rv_continuo...               0
#  1   <scipy.stats._distn_infrastructure.rv_continuo...               0
#  2   <scipy.stats._distn_infrastructure.rv_continuo...               0
#  3   <scipy.stats._distn_infrastructure.rv_continuo...               0
#  4   <scipy.stats._distn_infrastructure.rv_continuo...               0
#  5   <scipy.stats._distn_infrastructure.rv_continuo...               0
#  6   <scipy.stats._distn_infrastructure.rv_continuo...               0
#  7   <scipy.stats._distn_infrastructure.rv_continuo...               0
#  8   <scipy.stats._distn_infrastructure.rv_continuo...               0
#  9   <scipy.stats._distn_infrastructure.rv_continuo...               0
#  10  <scipy.stats._distn_infrastructure.rv_continuo...               0
#
#     bootstrap_pass    color
#  0            None  #e41a1c
#  1            None  #e41a1c
#  2            None  #377eb8
#  3            None  #4daf4a
#  4            None  #984ea3
#  5            None  #ff7f00
#  6            None  #ffff33
#  7            None  #a65628
#  8            None  #f781bf
#  9            None  #999999
#  10           None  #999999  ,
#  'histdata': (array([0.12004802, 0.        , 0.        , 0.        , 0.        ,
#          0.12805122, 0.        , 0.        , 0.        , 0.        ,
#          0.        , 0.24809924, 0.        , 0.        , 0.        ,
#          0.        , 0.        , 0.81232493, 0.        , 0.        ,
#          0.        , 0.        , 2.33293317, 0.        , 0.        ,
#          0.        , 0.        , 0.        , 1.70068027, 0.        ,
#          0.        , 0.        , 0.        , 0.        , 0.29211685,
#          0.        , 0.        , 0.        , 0.        , 0.08003201]),
#   array([2020.0875, 2020.2625, 2020.4375, 2020.6125, 2020.7875, 2020.9625,
#          2021.1375, 2021.3125, 2021.4875, 2021.6625, 2021.8375, 2022.0125,
#          2022.1875, 2022.3625, 2022.5375, 2022.7125, 2022.8875, 2023.0625,
#          2023.2375, 2023.4125, 2023.5875, 2023.7625, 2023.9375, 2024.1125,
#          2024.2875, 2024.4625, 2024.6375, 2024.8125, 2024.9875, 2025.1625,
#          2025.3375, 2025.5125, 2025.6875, 2025.8625, 2026.0375, 2026.2125,
#          2026.3875, 2026.5625, 2026.7375, 2026.9125])),
#  'size': 1428,
#  'alpha': 0.05,
#  'stats': 'RSS',
#  'bins': 'auto',
#  'bound': 'both',
#  'name': 'popular',
#  'method': 'parametric',
#  'multtest': 'fdr_bh',
#  'n_perm': 10000,
#  'smooth': None,
#  'weighted': True,
#  'f': 1.5,
#  'n_boots': None,
#  'random_state': None}

# %%
from scipy.stats import beta, norm, gamma
import warnings
import numpy as np
import random

# leto_normalized = (leto_gradnje - leto_gradnje.min() + random.randint(1,100)/100) / (leto_gradnje.max() - leto_gradnje.min())
# print(leto_normalized)
# pars_b = beta.fit(leto_gradnje, fscale=1000)
# print(pars_b)

# xb = np.linspace(leto_gradnje.min(), leto_gradnje.max(), 100)
# B_fit = [beta.pdf(x, *pars_b) for x in xb]

# plt.figure()
# plt.hist(leto_gradnje, bins="sqrt", density=True)
# # plt.hist(leto_normalized)
# plt.plot(xb, B_fit, label="Beta porazdelitev", linewidth=2.0)
# plt.legend();

# xb = np.linspace(leto_gradnje.min(), leto_gradnje.max(), 100)
# pars_norm = norm.fit(leto_gradnje)
# N_fit = [norm.pdf(x, *pars_norm) for x in xb ]
# plt.figure()
# plt.hist(leto_gradnje, bins="sqrt", density=True)
# plt.plot(xb, N_fit, label="normalna porazdelitev", linewidth=2.0)
# plt.legend();

# %%
def get_velikost(v):
    split_v = str(v).split()
    try:
        return float(split_v[0].replace(',', '.'))
    except ValueError:
        return None

def get_cena(c):
    c = str(c).split('€')[0].split('EUR')[0].replace('.', '').replace(',', '.').strip()

    try:
        return float(c)
    except ValueError:
        return None

def očisti_ceno(cena_str, velikost):
    if pd.isna(cena_str):
        return np.nan
    cena_str = str(cena_str).lower().replace("€", "").replace("€", "").replace(".", "").strip()
    
    try:
        if "m2" in cena_str:
            vrednost_na_m2 = float(cena_str.replace("m2", "").strip())
            return vrednost_na_m2 * velikost
        else:
            return float(cena_str)
    except:
        return np.nan

# %%
hs_df = kvadrati_gradnje_df[(kvadrati_gradnje_df['vrsta'] == "Stanovanje") | (kvadrati_gradnje_df['vrsta'] == "Hiša")]
hs_df = hs_df.copy()
hs_df['velikost_clean'] = hs_df['velikost'].apply(get_velikost)
# hs_df['cena_clean'] = hs_df['cena'].apply(get_cena)
hs_df['cena_clean'] = hs_df.apply(lambda row: očisti_ceno(row['cena'], row['velikost']), axis=1)
hs_df['cena_na_m2'] = hs_df['cena_clean'] / hs_df['velikost_clean']
hs_df
# Out:
#         id                          naslov   latitude  longitude  \
# 3        4  Goriška, Kanal ob Soči, Doblar  46.115738  13.687290
# 4        5       Podravska, Maribor, Pekre  46.543337  15.592553
# 7        8    Ljubljana okolica, Škofljica  45.985384  14.572855
# 8        9   Ljubljana, Vič-Rudnik, Trnovo  43.672248  18.448815
# 10      11                        Kaštelir  45.303995  13.688987
# ...    ...                             ...        ...        ...
# 6773  6789       Ljubljana okolica, Mengeš  46.162958  14.572217
# 6774  6791   Podravska, Starše, Zlatoličje  46.450693  15.790421
# 6775  6792                Ljubljana, Šiška  46.073720  14.485868
# 6776  6793   Ljubljana, Vič-Rudnik, Rudnik  50.444777  22.244033
# 6777  6794                            Umag  45.432359  13.522410
#
#      vrsta_prodaje       vrsta              tip   velikost  leto_gradnje  \
# 3          Prodaja        Hiša       Samostojna   223.6 m2        1924.0
# 4          Prodaja        Hiša  Večstanovanjska   322.6 m2        1973.0
# 7          Prodaja        Hiša       Samostojna     142 m2        2024.0
# 8          Prodaja        Hiša          Dvojček     217 m2        2020.0
# 10         Prodaja        Hiša          Dvojček     131 m2        2025.0
# ...            ...         ...              ...        ...           ...
# 6773       Prodaja        Hiša       Samostojna   535.4 m2        1841.0
# 6774       Prodaja        Hiša       Samostojna  150.23 m2        2025.0
# 6775       Prodaja  Stanovanje          4-sobno    93.1 m2        1983.0
# 6776       Prodaja  Stanovanje          4-sobno    97.2 m2        2020.0
# 6777       Prodaja  Stanovanje          2-sobno      65 m2        2019.0
#
#            cena     prodajalec_oseba       prodajalec_agencija  \
# 3     110.000 €           Jure Repše              RENES d.o.o.
# 4     579.000 €      Barbara Pečenik      BAZA AGENCIJA d.o.o.
# 7     585.000 €  Rojal invest d.o.o.       Rojal invest d.o.o.
# 8     864.000 €          NIKO MAUČEC  Mesto nepremičnin d.o.o.
# 10    592.000 €         Brane Koželj  NEPREMIČNINE PLUS d.o.o.
# ...         ...                  ...                       ...
# 6773  779.000 €       Erika Setnikar  NEPREMIČNINE PLUS d.o.o.
# 6774  280.000 €         Petra Vrečko       Agenti nepremičnine
# 6775  398.000 €        Urška Hočevar               Stan d.o.o.
# 6776  470.000 €  Rojal invest d.o.o.       Rojal invest d.o.o.
# 6777  235.000 €          Sara Ducman        INFINIS PROPERTIES
#
#                                                 splosno  \
# 3     Parcela:=17967 m2|Zgrajeno:=1924|Ener. izk.=G|...
# 4     Velikost (bruto):=322.6 m2|Parcela:=535 m2|Št....
# 7     Velikost (bruto):=142 m2|Parcela:=599 m2|Zgraj...
# 8     Velikost (neto):=217 m2|Velikost (bruto):=217 ...
# 10    Velikost (bruto):=131 m2|Parcela:=560 m2|Zgraj...
# ...                                                 ...
# 6773  Velikost (bruto):=535.4 m2|Parcela:=837 m2|Zgr...
# 6774  Velikost (bruto):=150.23 m2|Parcela:=402 m2|Št...
# 6775  Velikost (bruto):=93.1 m2|Zgrajeno:=1983|Adapt...
# 6776  Velikost (bruto):=97.2 m2|Nadstropje:=1|Zgraje...
# 6777  Velikost (bruto):=65 m2|Nadstropje:=Pritličje|...
#
#                                             znacilnosti  \
# 3                           Dodatno=Balkon/Atrij/Terasa
# 4     Ogrevanje=Toplotna črpalka|Luksuz=Klima/Lep ra...
# 7                                                   NaN
# 8     Dodatno=Vrt/Terasa/Pokrito parkirišče|Priključ...
# 10                                                  NaN
# ...                                                 ...
# 6773  Priključki=Telefon|Ogrevanje=Olje|Luksuz=Bliži...
# 6774  Ogrevanje=Toplotna črpalka|Luksuz=Bližina nara...
# 6775                  Dodatno=Dvigalo/Balkon/Parkirišče
# 6776                             Dodatno=Balkon/Dvigalo
# 6777  Ogrevanje=Toplotna črpalka/Talno gretje|Luksuz...
#
#                                                    opis  \
# 3     DOBLARSamostojna stanovanjska hiša velikosti 2...
# 4     Na odlični in mirni lokaciji v Pekrah prodamo ...
# 7     ŠKOFLJICA – NOVOGRADNJA – SAMOSTOJNE HIŠEŠKOFL...
# 8     Hiša dvojček v Trnovskem predmestju(P+1, novog...
# 10    Naprodaj je devet stanovanjskih enot v izmerah...
# ...                                                 ...
# 6773  Čudovita hiša z zgodovino in možnostjo preured...
# 6774  Novogradnja v ZlatoličjuV mirnem in urejenem n...
# 6775  LJ. ŠIŠKA, DRAVLJE, BLIŽINA ZELENIH POVRŠINide...
# 6776  Ljubljana, Peruzzijeva ulica –Vila Bober, stan...
# 6777  Prodamo čudovito 2-sobno stanovanje v luksuzne...
#
#                                                     url  velikost_clean  \
# 3     https://mojikvadrati.com/nepremicnina/424445-p...          223.60
# 4     https://mojikvadrati.com/nepremicnina/469054-p...          322.60
# 7     https://mojikvadrati.com/nepremicnina/449826-p...          142.00
# 8     https://mojikvadrati.com/nepremicnina/247131-p...          217.00
# 10    https://mojikvadrati.com/nepremicnina/476447-p...          131.00
# ...                                                 ...             ...
# 6773  https://mojikvadrati.com/nepremicnina/467843-p...          535.40
# 6774  https://mojikvadrati.com/nepremicnina/477521-p...          150.23
# 6775  https://mojikvadrati.com/nepremicnina/482910-p...           93.10
# 6776  https://mojikvadrati.com/nepremicnina/482529-p...           97.20
# 6777  https://mojikvadrati.com/nepremicnina/473926-p...           65.00
#
#       cena_clean   cena_na_m2
# 3       110000.0   491.949911
# 4       579000.0  1794.792312
# 7       585000.0  4119.718310
# 8       864000.0  3981.566820
# 10      592000.0  4519.083969
# ...          ...          ...
# 6773    779000.0  1454.986926
# 6774    280000.0  1863.808826
# 6775    398000.0  4274.973147
# 6776    470000.0  4835.390947
# 6777    235000.0  3615.384615
#
# [4383 rows x 19 columns]

# %%
plt.figure()
plt.hist(hs_df["cena_na_m2"], bins="sqrt")
plt.legend();

# %%
hs_df.sort_values("cena_na_m2", ascending=False).head(10)
# Out:
#         id                                             naslov   latitude  \
# 6156  6168                                               Nica  43.700936
# 666    668  Hrvaška, Novigrad-Cittanova, Novigrad - Kariga...  45.315918
# 2197  2199                             Obalno - kraška, Izola  45.539894
# 2596  2598                                  Ljubljana, Center  31.795281
# 5943  5953                    Obalno - kraška, Piran, Razgled  46.217725
# 3591  3594                    Tujina, LUKSEMBURG,  BASCHARAGE  49.571269
# 6335  6349                                             Tujina        NaN
# 6485  6500                   Obalno - kraška, Koper, Kolomban  45.588146
# 3084  3086                   Obalno - kraška, Koper, Kolomban  45.588146
# 5052  5059                    Tujina, LUKSEMBURG,  BASCHARAGE  49.571269
#
#       longitude vrsta_prodaje       vrsta         tip  velikost  leto_gradnje  \
# 6156   7.268391       Prodaja        Hiša  Samostojna    643 m2        1911.0
# 666   13.563028       Prodaja        Hiša  Samostojna    200 m2        2024.0
# 2197  13.659390       Prodaja        Hiša  Samostojna     60 m2        1900.0
# 2596 -94.180358       Prodaja  Stanovanje     2-sobno   80.1 m2        2022.0
# 5943  15.400981       Prodaja        Hiša  Samostojna    110 m2        1900.0
# 3591   5.912845       Prodaja  Stanovanje     3-sobno  99.65 m2        2019.0
# 6335        NaN       Prodaja        Hiša  Samostojna    315 m2        1890.0
# 6485  13.750442       Prodaja        Hiša  Samostojna     82 m2        1985.0
# 3084  13.750442       Prodaja        Hiša  Samostojna     82 m2        1985.0
# 5052   5.912845       Prodaja  Stanovanje     3-sobno  81.91 m2        2019.0
#
#               cena     prodajalec_oseba  \
# 6156  47.000.000 €        BAZA AGENCIJA
# 666    4.700.000 €         Romana Johan
# 2197     900.000 €                  NaN
# 2596   1.150.000 €         Jernej Banfi
# 5943   1.499.000 €        Gordana Kovač
# 3591   1.333.710 €                  NaN
# 6335   4.200.000 €  URBANISTIKA, d.o.o.
# 6485   1.080.000 €        Mary Markežič
# 3084   1.080.000 €        Mary Markežič
# 5052   1.012.380 €                  NaN
#
#                            prodajalec_agencija  \
# 6156                      BAZA AGENCIJA d.o.o.
# 666         LARES NEPREMIČNINSKA DRUŽBA d.o.o.
# 2197                       Zeta, d.o.o., Piran
# 2596                      CENTURY 21 Slovenija
# 5943  ORIZONT NEPREMIČNINE, Gordana Kovač s.p.
# 3591                     Altum AE Group d.o.o.
# 6335                        Urbanistika d.o.o.
# 6485                          RUJ nepremičnine
# 3084                          RUJ nepremičnine
# 5052                     Altum AE Group d.o.o.
#
#                                                 splosno  \
# 6156  Velikost (bruto):=643 m2|Parcela:=16500 m2|Št....
# 666   Velikost (bruto):=200 m2|Parcela:=350 m2|Zgraj...
# 2197  Velikost (bruto):=60 m2|Parcela:=2907 m2|Zgraj...
# 2596  Nadstropje:=3|Št. spalnic=1|Zgrajeno:=2022|Sta...
# 5943  Velikost (neto):=100 m2|Velikost (bruto):=110 ...
# 3591  Velikost (bruto):=99.65 m2|Nadstropje:=Pritlič...
# 6335  Velikost (bruto):=315 m2|Parcela:=8001 m2|Zgra...
# 6485  Velikost (bruto):=82 m2|Parcela:=1737 m2|Št. s...
# 3084  Velikost (bruto):=82 m2|Parcela:=1737 m2|Št. s...
# 5052  Velikost (bruto):=81.91 m2|Nadstropje:=2/3|Zgr...
#
#                                             znacilnosti  \
# 6156  Luksuz=Fitnes/Bazen/Lep razgled/Bližina narave...
# 666                                                 NaN
# 2197                                                NaN
# 2596  Priključki=Telefon/Kabelski priklj./Optika|Ogr...
# 5943  Ogrevanje=CK|Lega=Jug|Luksuz=Lep razgled/Bliži...
# 3591  Dodatno=Atrij/Parkirišče/Terasa|Ogrevanje=Topl...
# 6335                                                NaN
# 6485  Ogrevanje=Elektrika/Klima|Luksuz=Lep razgled/B...
# 3084  Ogrevanje=Elektrika/Klima|Luksuz=Lep razgled/B...
# 5052  Dodatno=Balkon/Parkirišče/Terasa|Ogrevanje=Top...
#
#                                                    opis  \
# 6156  Na francoski rivieri, v obmorskem mestecu v bl...
# 666   Novigrad - Karigador - 12 HIŠIstra KarigadorIŠ...
# 2197  IZOLAOdličen panoramski razgled na morje in Iz...
# 2596  PRODAMO LUKSUZNO STANOVANJE V TOP CENTRU LJUBL...
# 5943  Piran; na odlični lokaciji, z odprtim pogledom...
# 3591  LUKSEMBURG, BASCHARAGEProstorno 3-sobno stanov...
# 6335  TRIESTE - MUGGIA - LAZZARETTOMILJE - LAZARET O...
# 6485  Hiša+zazidljiva parcela KolombanNa čudoviti in...
# 3084  Samostojna hiša KolombanNa čudoviti in mirni l...
# 5052  LUKSEMBURG, BASCHARAGESvetlo 3-sobno stanovanj...
#
#                                                     url  velikost_clean  \
# 6156  https://mojikvadrati.com/nepremicnina/450274-p...          643.00
# 666   https://mojikvadrati.com/nepremicnina/465401-p...          200.00
# 2197  https://mojikvadrati.com/nepremicnina/434910-p...           60.00
# 2596  https://mojikvadrati.com/nepremicnina/481049-p...           80.10
# 5943  https://mojikvadrati.com/nepremicnina/481504-p...          110.00
# 3591  https://mojikvadrati.com/nepremicnina/469348-p...           99.65
# 6335  https://mojikvadrati.com/nepremicnina/469436-p...          315.00
# 6485  https://mojikvadrati.com/nepremicnina/475190-p...           82.00
# 3084  https://mojikvadrati.com/nepremicnina/474216-p...           82.00
# 5052  https://mojikvadrati.com/nepremicnina/482342-p...           81.91
#
#       cena_clean    cena_na_m2
# 6156  47000000.0  73094.867807
# 666    4700000.0  23500.000000
# 2197    900000.0  15000.000000
# 2596   1150000.0  14357.053683
# 5943   1499000.0  13627.272727
# 3591   1333710.0  13383.943803
# 6335   4200000.0  13333.333333
# 6485   1080000.0  13170.731707
# 3084   1080000.0  13170.731707
# 5052   1012380.0  12359.663045

# %%
hs_df = hs_df[hs_df["cena_na_m2"] <= 15000]
plt.figure()
plt.hist(hs_df["cena_na_m2"], bins="sqrt")
plt.legend();

# %% [markdown]
# Izstopa Schellenburg, luksuz v Ljubljani, BASCHARAGE v Luksemburgu, ena garsonjera v Piranu.

# %%
cena_na_m2 = hs_df["cena_na_m2"].dropna()

dist = distfit()
dist.fit_transform(cena_na_m2)
# Out:
# 12-04-25 21:56:57 [distfit.distfit] > INFO     > fit
# 12-04-25 21:56:57 [distfit.distfit] > INFO     > transform
# 12-04-25 21:56:57 [distfit.distfit] > INFO     > [norm      ] [0.00 sec] [RSS: 2.67425e-08] [loc=3211.359 scale=1889.770]
# 12-04-25 21:56:57 [distfit.distfit] > INFO     > [expon     ] [0.00 sec] [RSS: 1.94438e-07] [loc=1.250 scale=3210.109]
# 12-04-25 21:56:57 [distfit.distfit] > INFO     > [pareto    ] [0.00 sec] [RSS: 1.94438e-07] [loc=-274877906942.750 scale=274877906944.000]
# 12-04-25 21:56:57 [distfit.distfit] > INFO     > [dweibull  ] [0.02 sec] [RSS: 3.69511e-08] [loc=3139.727 scale=1553.477]
# 12-04-25 21:56:58 [distfit.distfit] > INFO     > [t         ] [0.09 sec] [RSS: 2.67423e-08] [loc=3211.357 scale=1889.767]
# 12-04-25 21:56:58 [distfit.distfit] > INFO     > [genextreme] [0.06 sec] [RSS: 5.69308e-07] [loc=4.158 scale=15.052]
# 12-04-25 21:56:58 [distfit.distfit] > INFO     > [gamma     ] [0.01 sec] [RSS: 1.34834e-08] [loc=-223.419 scale=1062.113]
# 12-04-25 21:56:58 [distfit.distfit] > INFO     > [lognorm   ] [0.00 sec] [RSS: 1.57312e-08] [loc=-1604.355 scale=4476.725]
# 12-04-25 21:56:58 [distfit.distfit] > INFO     > [beta      ] [0.04 sec] [RSS: 1.247e-08] [loc=-138.524 scale=53286.452]
# 12-04-25 21:56:58 [distfit.distfit] > INFO     > [uniform   ] [0.00 sec] [RSS: 3.35979e-07] [loc=1.250 scale=14998.750]
# 12-04-25 21:56:58 [distfit.distfit] > INFO     > [loggamma  ] [0.02 sec] [RSS: 2.71719e-08] [loc=-599157.571 scale=80443.183]
# 12-04-25 21:56:58 [distfit.distfit] > INFO     > [norm      ] [0.28 sec] [RSS: 2.67425e-08] [loc=3211.359 scale=1889.770]
# 12-04-25 21:56:58 [distfit.distfit] > INFO     > [expon     ] [0.28 sec] [RSS: 1.94438e-07] [loc=1.250 scale=3210.109]
# 12-04-25 21:56:58 [distfit.distfit] > INFO     > [pareto    ] [0.28 sec] [RSS: 1.94438e-07] [loc=-274877906942.750 scale=274877906944.000]
# 12-04-25 21:56:58 [distfit.distfit] > INFO     > [dweibull  ] [0.27 sec] [RSS: 3.69511e-08] [loc=3139.727 scale=1553.477]
# 12-04-25 21:56:58 [distfit.distfit] > INFO     > [t         ] [0.25 sec] [RSS: 2.67423e-08] [loc=3211.357 scale=1889.767]
# 12-04-25 21:56:58 [distfit.distfit] > INFO     > [genextreme] [0.15 sec] [RSS: 5.69308e-07] [loc=4.158 scale=15.052]
# 12-04-25 21:56:58 [distfit.distfit] > INFO     > [gamma     ] [0.09 sec] [RSS: 1.34834e-08] [loc=-223.419 scale=1062.113]
# 12-04-25 21:56:58 [distfit.distfit] > INFO     > [lognorm   ] [0.08 sec] [RSS: 1.57312e-08] [loc=-1604.355 scale=4476.725]
# 12-04-25 21:56:58 [distfit.distfit] > INFO     > [beta      ] [0.07 sec] [RSS: 1.247e-08] [loc=-138.524 scale=53286.452]
# 12-04-25 21:56:58 [distfit.distfit] > INFO     > [uniform   ] [0.02 sec] [RSS: 3.35979e-07] [loc=1.250 scale=14998.750]
# 12-04-25 21:56:58 [distfit.distfit] > INFO     > [loggamma  ] [0.02 sec] [RSS: 2.71719e-08] [loc=-599157.571 scale=80443.183]
# 12-04-25 21:56:58 [distfit.distfit] > INFO     > Compute confidence intervals [parametric]
# {'model': {'name': 'beta',
#   'score': 1.2469964525703652e-08,
#   'loc': -138.52384301001,
#   'scale': 53286.451907258335,
#   'arg': (np.float64(2.8525787481841114), np.float64(42.526012158876426)),
#   'params': (np.float64(2.8525787481841114),
#    np.float64(42.526012158876426),
#    np.float64(-138.52384301001),
#    np.float64(53286.451907258335)),
#   'model': <scipy.stats._distn_infrastructure.rv_continuous_frozen at 0x113053fb0>,
#   'bootstrap_score': 0,
#   'bootstrap_pass': None,
#   'color': '#e41a1c',
#   'CII_min_alpha': np.float64(765.1042035250832),
#   'CII_max_alpha': np.float64(6815.823534421345)},
#  'summary':           name     score              loc                scale  \
#  0         beta       0.0      -138.523843         53286.451907
#  1        gamma       0.0      -223.418544          1062.113129
#  2      lognorm       0.0     -1604.355416          4476.725328
#  3            t       0.0      3211.357058          1889.766694
#  4         norm       0.0      3211.359243          1889.769946
#  5     loggamma       0.0   -599157.571042         80443.182526
#  6     dweibull       0.0      3139.727328          1553.476671
#  7        expon       0.0             1.25          3210.109243
#  8       pareto       0.0 -274877906942.75  274877906943.999969
#  9      uniform       0.0             1.25             14998.75
#  10  genextreme  0.000001         4.158445            15.052486
#
#                                           arg  \
#  0   (2.8525787481841114, 42.526012158876426)
#  1                      (3.2339095769465813,)
#  2                      (0.3836382860857968,)
#  3                      (1377844.4294210528,)
#  4                                         ()
#  5                      (1786.9863521624354,)
#  6                      (1.2353152559545357,)
#  7                                         ()
#  8                       (85628833.26023649,)
#  9                                         ()
#  10                    (-5.1750235100948405,)
#
#                                                 params  \
#  0   (2.8525787481841114, 42.526012158876426, -138....
#  1   (3.2339095769465813, -223.41854409280768, 1062...
#  2   (0.3836382860857968, -1604.3554161893258, 4476...
#  3   (1377844.4294210528, 3211.357058242552, 1889.7...
#  4            (3211.3592430558324, 1889.7699464179605)
#  5   (1786.9863521624354, -599157.5710422532, 80443...
#  6   (1.2353152559545357, 3139.7273280906697, 1553....
#  7                          (1.25, 3210.1092430558324)
#  8   (85628833.26023649, -274877906942.75, 27487790...
#  9                                    (1.25, 14998.75)
#  10  (-5.1750235100948405, 4.158444815485636, 15.05...
#
#                                                  model bootstrap_score  \
#  0   <scipy.stats._distn_infrastructure.rv_continuo...               0
#  1   <scipy.stats._distn_infrastructure.rv_continuo...               0
#  2   <scipy.stats._distn_infrastructure.rv_continuo...               0
#  3   <scipy.stats._distn_infrastructure.rv_continuo...               0
#  4   <scipy.stats._distn_infrastructure.rv_continuo...               0
#  5   <scipy.stats._distn_infrastructure.rv_continuo...               0
#  6   <scipy.stats._distn_infrastructure.rv_continuo...               0
#  7   <scipy.stats._distn_infrastructure.rv_continuo...               0
#  8   <scipy.stats._distn_infrastructure.rv_continuo...               0
#  9   <scipy.stats._distn_infrastructure.rv_continuo...               0
#  10  <scipy.stats._distn_infrastructure.rv_continuo...               0
#
#     bootstrap_pass    color
#  0            None  #e41a1c
#  1            None  #e41a1c
#  2            None  #377eb8
#  3            None  #4daf4a
#  4            None  #984ea3
#  5            None  #ff7f00
#  6            None  #ffff33
#  7            None  #a65628
#  8            None  #f781bf
#  9            None  #999999
#  10           None  #999999  ,
#  'histdata': (array([2.55241688e-05, 9.35886189e-05, 1.50824634e-04, 1.60106150e-04,
#          2.11154487e-04, 1.83309939e-04, 1.88724157e-04, 2.36678656e-04,
#          2.08060649e-04, 2.25076761e-04, 2.13474866e-04, 1.98005673e-04,
#          2.21209463e-04, 1.60106150e-04, 1.23753546e-04, 1.44636956e-04,
#          9.82293768e-05, 1.19112788e-04, 9.90028365e-05, 5.33687165e-05,
#          3.86729830e-05, 3.78995233e-05, 1.70161125e-05, 2.24303301e-05,
#          1.16018949e-05, 1.23753546e-05, 1.31488142e-05, 9.28151592e-06,
#          6.96113694e-06, 7.73459660e-06, 6.96113694e-06, 6.18767728e-06,
#          1.00549756e-05, 1.54691932e-06, 2.32037898e-06, 1.54691932e-06,
#          0.00000000e+00, 1.54691932e-06, 0.00000000e+00, 3.86729830e-06,
#          2.32037898e-06, 7.73459660e-07, 0.00000000e+00, 1.54691932e-06,
#          1.54691932e-06, 7.73459660e-07, 0.00000000e+00, 7.73459660e-07,
#          0.00000000e+00, 7.73459660e-07]),
#   array([  151.2375,   451.2125,   751.1875,  1051.1625,  1351.1375,
#           1651.1125,  1951.0875,  2251.0625,  2551.0375,  2851.0125,
#           3150.9875,  3450.9625,  3750.9375,  4050.9125,  4350.8875,
#           4650.8625,  4950.8375,  5250.8125,  5550.7875,  5850.7625,
#           6150.7375,  6450.7125,  6750.6875,  7050.6625,  7350.6375,
#           7650.6125,  7950.5875,  8250.5625,  8550.5375,  8850.5125,
#           9150.4875,  9450.4625,  9750.4375, 10050.4125, 10350.3875,
#          10650.3625, 10950.3375, 11250.3125, 11550.2875, 11850.2625,
#          12150.2375, 12450.2125, 12750.1875, 13050.1625, 13350.1375,
#          13650.1125, 13950.0875, 14250.0625, 14550.0375, 14850.0125])),
#  'size': 4310,
#  'alpha': 0.05,
#  'stats': 'RSS',
#  'bins': 'auto',
#  'bound': 'both',
#  'name': 'popular',
#  'method': 'parametric',
#  'multtest': 'fdr_bh',
#  'n_perm': 10000,
#  'smooth': None,
#  'weighted': True,
#  'f': 1.5,
#  'n_boots': None,
#  'random_state': None}

# %% [markdown]
# Zgleda je Beta porazdelitev.

# %%
# leto_normalized = (leto_gradnje - leto_gradnje.min() + random.randint(1,100)/100) / (leto_gradnje.max() - leto_gradnje.min())
# print(leto_normalized)
pars_b = beta.fit(cena_na_m2)
print(pars_b)

xb = np.linspace(cena_na_m2.min(), cena_na_m2.max(), 1000)
B_fit = [beta.pdf(x, *pars_b) for x in xb]

plt.figure()
plt.hist(cena_na_m2, bins="sqrt", density=True)
# plt.hist(leto_normalized)
plt.plot(xb, B_fit, label="Beta porazdelitev", linewidth=2.0)
plt.legend();
# Out:
# (np.float64(2.8525787481841114), np.float64(42.526012158876426), np.float64(-138.52384301001), np.float64(53286.451907258335))

# %%
import scipy.stats as stats

plt.figure(figsize=(8, 5))
stats.probplot(cena_na_m2, dist="beta", sparams=pars_b, plot=plt)
plt.title("Beta porazdelitev")

plt.show()

# %% [markdown]
# Beta tukaj super fitta. Poglejmo osamelce zgoraj in spodaj.

# %% [markdown]
# Tudi gamma dobro fita.

# %%
pars_g = gamma.fit(cena_na_m2)
print(pars_g)

xb = np.linspace(cena_na_m2.min(), cena_na_m2.max(), 1000)
G_fit = [gamma.pdf(x, *pars_g) for x in xb]

plt.figure()
plt.hist(cena_na_m2, bins="sqrt", density=True)
# plt.hist(leto_normalized)
plt.plot(xb, G_fit, label="Gamma porazdelitev", linewidth=2.0)
plt.legend();
# Out:
# (np.float64(3.2339095769465813), np.float64(-223.41854409280768), np.float64(1062.1131294591003))

# %%
cena_na_m2.median()
# Out:
# np.float64(2967.133620689655)

# %%
quantile_95 = beta.ppf(0.975, *pars_b)
quantile_05 = beta.ppf(0.025, *pars_b)

print(quantile_95)
print(quantile_05)

ltx = xb[xb >= quantile_95]
B_ltx = [beta.pdf(x, *pars_b) for x in ltx] 

gtx = xb[xb <= quantile_05]
B_gtx = [beta.pdf(x, *pars_b) for x in gtx]

plt.figure(figsize=(8, 5))
plt.hist(cena_na_m2, bins="sqrt", density=True, color="#87CEEBaa")

# plt.axvline(beta.ppf(0.95, *pars_b), color='red', linestyle='--', label='p = 0.05')
plt.fill_between(ltx, 0, B_ltx, alpha=0.4, color="red")

# plt.axvline(beta.ppf(0.05, *pars_b), color='red', linestyle='--', label='p = 0.05')
plt.fill_between(gtx, 0, B_gtx, alpha=0.4, color="red")

plt.plot(xb, B_fit, label="Beta porazdelitev", linewidth=2.0)
plt.xlabel("Normalizirana varianca ocen filma")
plt.ylabel("Število filmov")
plt.legend()
plt.show()
# Out:
# 7782.171324094994
# 539.2607351957629

# %%
hs_df.sort_values("cena_na_m2").head(20)
# Out:
#         id                                             naslov   latitude  \
# 4422  4427                       Gorenjska, Šenčur, Prebačevo  46.212183
# 6754  6770            Jugovzhodna Slovenija, Škocjan, Gabrnik  45.726623
# 3180  3182               Obalno - kraška, Koper, Žusterna III  45.547986
# 6026  6038                     Obalno - kraška, Piran, Lucija  45.507080
# 3792  3795                   Spodnjeposavska, Brežice, Kapele  45.930371
# 4122  4127                          Koroška, Črna na Koroškem  46.469632
# 768    770                     Jugovzhodna Slovenija, Metlika  45.650103
# 4682  4689                             Pomurska, Apače, Črnci  46.694370
# 6753  6769               Goriška, Nova Gorica, Grgarske Ravne  46.032093
# 5262  5269             Notranjsko - kraška, Postojna, Planina  45.861802
# 1082  1084                                   Gorenjska, Kranj  46.243291
# 6698  6714                            Obalno - kraška, Divača  45.682790
# 719    721                                 Pomurska, Ljutomer  46.518705
# 239    240                     Pomurska, Šalovci, Domanjševci  46.780358
# 3387  3390                              Goriška, Vipava, Lože  44.286009
# 4310  4315                   Savinjska, Laško, Rimske Toplice  46.123665
# 1184  1186                            Spodnjeposavska, Radeče  46.066132
# 3196  3198                  Jugovzhodna Slovenija, Šentjernej  45.843295
# 3786  3789  Jugovzhodna Slovenija, Dolenjske Toplice,  OBČICE  45.705999
# 2280  2282                           Podravska, Ruše, Lobnica  46.498334
#
#       longitude vrsta_prodaje       vrsta         tip   velikost  \
# 4422  14.397890       Prodaja  Stanovanje   4,5-sobno     200 m2
# 6754  14.211984       Prodaja        Hiša     Kmetija  190000 m2
# 3180  13.730478       Prodaja  Stanovanje     3-sobno   12855 m2
# 6026  13.604638       Prodaja        Hiša  Samostojna   12675 m2
# 3792  15.676048       Prodaja        Hiša      Vrstna    1350 m2
# 4122  14.850264       Prodaja        Hiša  Samostojna     688 m2
# 768   15.317448       Prodaja        Hiša  Samostojna   360.4 m2
# 4682  15.890904       Prodaja        Hiša        Vila    1570 m2
# 6753  13.668327       Prodaja        Hiša  Samostojna     547 m2
# 5262  14.274964       Prodaja        Hiša  Samostojna     240 m2
# 1082  14.354935       Prodaja        Hiša  Samostojna    1959 m2
# 6698  13.968573       Prodaja        Hiša  Samostojna     682 m2
# 719   16.196740       Prodaja        Hiša  Samostojna     200 m2
# 239   16.307652       Prodaja        Hiša  Samostojna   216.4 m2
# 3387   1.794381       Prodaja        Hiša     Kmetija  803.64 m2
# 4310  15.203055       Prodaja        Hiša  Samostojna     360 m2
# 1184  15.181876       Prodaja        Hiša  Samostojna   401.1 m2
# 3196  15.338473       Prodaja        Hiša  Samostojna     889 m2
# 3786  15.076241       Prodaja        Hiša  Samostojna   270.2 m2
# 2280  15.453163       Prodaja        Hiša  Samostojna     162 m2
#
#       leto_gradnje       cena   prodajalec_oseba  \
# 4422        1985.0      250 €                NaN
# 6754        1900.0  885.000 €    Boštjan Blatnik
# 3180        2010.0  468.000 €                NaN
# 6026        1890.0  609.000 €       Boris Sardot
# 3792        1930.0  150.000 €                NaN
# 4122        1820.0   80.000 €       Franci Repše
# 768         1900.0   45.000 €        Jožica Kobe
# 4682        1760.0  250.000 €        Klara Šinko
# 6753        1935.0   90.000 €       Franci Repše
# 5262        1750.0   45.000 €        Jernej Suša
# 1082        1959.0  369.000 €     Vesna Osterman
# 6698        1800.0  129.000 €                NaN
# 719         1799.0   39.500 €      Tomaž Poredoš
# 239         1912.0   43.000 €       Jernej Banfi
# 3387        1600.0  162.000 €        Jernej Suša
# 4310        1938.0   75.000 €                NaN
# 1184        1934.0   85.000 €  Robert Nedanovski
# 3196        1600.0  190.000 €  Majda Starovašnik
# 3786        1995.0   59.000 €                NaN
# 2280        1986.0   38.000 €      Aljaž Berginc
#
#                       prodajalec_agencija  \
# 4422                                  NaN
# 6754                     ABC nepremičnine
# 3180                                  NaN
# 6026                          KW Slovenia
# 3792                                  NaN
# 4122                         RENES d.o.o.
# 768              NNRN Nepremičnine d.o.o.
# 4682                    AGENT 3091 d.o.o.
# 6753                         RENES d.o.o.
# 5262                     RUJ nepremičnine
# 1082             ITD nepremičnine, d.o.o.
# 6698                        Trobec d.o.o.
# 719   Nepremičnine SV, Tomaž Poredoš s.p.
# 239                  CENTURY 21 Slovenija
# 3387                     RUJ nepremičnine
# 4310                                  NaN
# 1184             NNRN Nepremičnine d.o.o.
# 3196                 CENTURY 21 Slovenija
# 3786          Kvadrat nepremičnine d.o.o.
# 2280                         24nep d.o.o.
#
#                                                 splosno  \
# 4422  Velikost (bruto):=200 m2|Nadstropje:=Pritličje...
# 6754  Parcela:=190000 m2|Zgrajeno:=1900|Ener. izk.=F...
# 3180  Velikost (bruto):=12855 m2|Nadstropje:=Visoko ...
# 6026  Velikost (neto):=200 m2|Parcela:=12675 m2|Zgra...
# 3792  Velikost (bruto):=1350 m2|Zgrajeno:=1930|Šifra...
# 4122  Velikost (bruto):=688 m2|Zgrajeno:=1820|Ener. ...
# 768   Velikost (bruto):=360.4 m2|Parcela:=472 m2|Zgr...
# 4682  Velikost (bruto):=1570 m2|Parcela:=2748 m2|Zgr...
# 6753  Velikost (bruto):=547 m2|Parcela:=124424 m2|Zg...
# 5262  Velikost (bruto):=240 m2|Parcela:=306 m2|Zgraj...
# 1082  Velikost (bruto):=1959 m2|Parcela:=604 m2|Št. ...
# 6698  Velikost (bruto):=682 m2|Parcela:=1151 m2|Zgra...
# 719   Velikost (bruto):=200 m2|Parcela:=146 m2|Zgraj...
# 239   Velikost (neto):=216.4 m2|Velikost (bruto):=21...
# 3387  Velikost (bruto):=803.64 m2|Parcela:=708 m2|Zg...
# 4310  Velikost (bruto):=360 m2|Zgrajeno:=1938|Šifra:...
# 1184  Velikost (bruto):=401.1 m2|Parcela:=798 m2|Zgr...
# 3196  Velikost (neto):=889 m2|Velikost (bruto):=889 ...
# 3786  Velikost (bruto):=270.2 m2|Parcela:=1193 m2|Zg...
# 2280  Velikost (bruto):=162 m2|Parcela:=2271 m2|Zgra...
#
#                                             znacilnosti  \
# 4422  Dodatno=Balkon/Klet/Parkirišče/Garaža/Shramba/...
# 6754                                                NaN
# 3180  Dodatno=Balkon/Terasa/Klet/Pokrito parkirišče/...
# 6026                                                NaN
# 3792                                                NaN
# 4122                                                NaN
# 768                                                 NaN
# 4682                                                NaN
# 6753                                                NaN
# 5262                 Priključki=Greznica|Lega=Sever/Jug
# 1082  Priključki=Optika/Kabelski priklj.|Lega=Sever/Jug
# 6698                                                NaN
# 719                                                 NaN
# 239                   Lega=Jug/Vzhod|Luksuz=Lep razgled
# 3387                                     Lega=Jug/Zahod
# 4310                                                NaN
# 1184                                                NaN
# 3196      Luksuz=Lep razgled/Bližina narave/Zelo sončno
# 3786                                                NaN
# 2280  Lega=Sever/Jug/Vzhod/Zahod|Luksuz=Bližina nara...
#
#                                                    opis  \
# 4422  Prodamo stanovanje v stanovanjski hiši.Prodaja...
# 6754  GABRNIKPosavje, Škocjan, zelo lepo in vzdrževa...
# 3180  KOPER - NOKTURNO,128,55m2, trisobno, ekskluziv...
# 6026  V Luciji prodamo samostojno starejšo hišo oz. ...
# 3792  Prodam hišo in pripadajoče zemljišče v Kapelah...
# 4122                                                NaN
# 768   METLIKAMETLIKA, Cesta bratstva in enotnosti,pr...
# 4682  Dvorec FreudenauDvorec Freudenau se nahaja v k...
# 6753  GRGARSKE RAVNEPoslovnostanovanjski objekt veli...
# 5262  Hiša v zadnjih 25 letih ni bila naseljena. V p...
# 1082  Na Primskovem v Kranju je na voljo samostojna ...
# 6698  DIVAČAna parceli so ruševine threh stavb, ki s...
# 719   LJUTOMEROdlična investicija v prenovo stare lj...
# 239   LASTNOSTI NEPREMIČNINE:Izgradnja: 1912Lokacija...
# 3387  Starejša kamnita hiša z notranjim dvoriščemSam...
# 4310  Na relaciji Rimske Toplice – Hrastnik tik ob r...
# 1184  RADEČERADEČE, Starograjska ulica, prodamo samo...
# 3196  Srednjeveški dvonadstropni  dvorec  na edinstv...
# 3786  DOLENJSKE TOPLICE, OBČICEhiša v 3.GF, na mirni...
# 2280  V OBJEMU NARAVEVIKEND V NARAVIRuše, Lobnica: P...
#
#                                                     url  velikost_clean  \
# 4422  https://mojikvadrati.com/nepremicnina/471478-p...          200.00
# 6754  https://mojikvadrati.com/nepremicnina/469853-p...       190000.00
# 3180  https://mojikvadrati.com/nepremicnina/481376-p...        12855.00
# 6026  https://mojikvadrati.com/nepremicnina/417750-p...        12675.00
# 3792  https://mojikvadrati.com/nepremicnina/467450-p...         1350.00
# 4122  https://mojikvadrati.com/nepremicnina/473108-p...          688.00
# 768   https://mojikvadrati.com/nepremicnina/480023-p...          360.40
# 4682  https://mojikvadrati.com/nepremicnina/470429-p...         1570.00
# 6753  https://mojikvadrati.com/nepremicnina/424566-p...          547.00
# 5262  https://mojikvadrati.com/nepremicnina/367059-p...          240.00
# 1082  https://mojikvadrati.com/nepremicnina/482872-p...         1959.00
# 6698  https://mojikvadrati.com/nepremicnina/439114-p...          682.00
# 719   https://mojikvadrati.com/nepremicnina/470341-p...          200.00
# 239   https://mojikvadrati.com/nepremicnina/455016-p...          216.40
# 3387  https://mojikvadrati.com/nepremicnina/436470-p...          803.64
# 4310  https://mojikvadrati.com/nepremicnina/477595-p...          360.00
# 1184  https://mojikvadrati.com/nepremicnina/480147-p...          401.10
# 3196  https://mojikvadrati.com/nepremicnina/452660-p...          889.00
# 3786  https://mojikvadrati.com/nepremicnina/470742-p...          270.20
# 2280  https://mojikvadrati.com/nepremicnina/481675-p...          162.00
#
#       cena_clean  cena_na_m2
# 4422       250.0    1.250000
# 6754    885000.0    4.657895
# 3180    468000.0   36.406068
# 6026    609000.0   48.047337
# 3792    150000.0  111.111111
# 4122     80000.0  116.279070
# 768      45000.0  124.861265
# 4682    250000.0  159.235669
# 6753     90000.0  164.533821
# 5262     45000.0  187.500000
# 1082    369000.0  188.361409
# 6698    129000.0  189.149560
# 719      39500.0  197.500000
# 239      43000.0  198.706100
# 3387    162000.0  201.582798
# 4310     75000.0  208.333333
# 1184     85000.0  211.917228
# 3196    190000.0  213.723285
# 3786     59000.0  218.356773
# 2280     38000.0  234.567901

# %% [markdown]
# Dosti jih je takih, ki so dali ceno na m2 in smo narobe parsali. En iz Kopra je pozabil vejico pri velikosti in ima 12855 m2 namesto 128,55 m2. Večina poceni nepremičnin je zanemarjenih ali ne do konca zgrajenih (shocker).

# %%
hs_df.sort_values("cena_na_m2", ascending=False).head(20)
# Out:
#         id                                     naslov   latitude  longitude  \
# 2197  2199                     Obalno - kraška, Izola  45.539894  13.659390
# 2596  2598                          Ljubljana, Center  31.795281 -94.180358
# 5943  5953            Obalno - kraška, Piran, Razgled  46.217725  15.400981
# 3591  3594            Tujina, LUKSEMBURG,  BASCHARAGE  49.571269   5.912845
# 6335  6349                                     Tujina        NaN        NaN
# 3084  3086           Obalno - kraška, Koper, Kolomban  45.588146  13.750442
# 6485  6500           Obalno - kraška, Koper, Kolomban  45.588146  13.750442
# 5052  5059            Tujina, LUKSEMBURG,  BASCHARAGE  49.571269   5.912845
# 1017  1019                                   Marbella  36.508976  -4.885620
# 348    349       Obalno - kraška, Piran, Piran/Pirano  45.528492  13.568449
# 3016  3018                      Mali Lošinj, Nerezine  44.658877  14.396724
# 3647  3650            Tujina, LUKSEMBURG,  BASCHARAGE  49.571269   5.912845
# 6281  6293                          Ljubljana, Center  31.795281 -94.180358
# 167    168  Obalno - kraška, Koper,  EKSKLUZIVNA VILA  45.547986  13.730478
# 6385  6400            Tujina, LUKSEMBURG,  BASCHARAGE  49.571269   5.912845
# 6207  6219        Ljubljana, Vič-Rudnik, Rožna dolina  45.942269  13.646351
# 4925  4932                          Ljubljana, Center  31.795281 -94.180358
# 1036  1038                          Ljubljana, Center  31.795281 -94.180358
# 4999  5006                     Obalno - kraška, Izola  45.539894  13.659390
# 3608  3611                          Ljubljana, Center  31.795281 -94.180358
#
#      vrsta_prodaje       vrsta         tip   velikost  leto_gradnje  \
# 2197       Prodaja        Hiša  Samostojna      60 m2        1900.0
# 2596       Prodaja  Stanovanje     2-sobno    80.1 m2        2022.0
# 5943       Prodaja        Hiša  Samostojna     110 m2        1900.0
# 3591       Prodaja  Stanovanje     3-sobno   99.65 m2        2019.0
# 6335       Prodaja        Hiša  Samostojna     315 m2        1890.0
# 3084       Prodaja        Hiša  Samostojna      82 m2        1985.0
# 6485       Prodaja        Hiša  Samostojna      82 m2        1985.0
# 5052       Prodaja  Stanovanje     3-sobno   81.91 m2        2019.0
# 1017       Prodaja        Hiša  Samostojna     261 m2        2024.0
# 348        Prodaja  Stanovanje  Garsonjera      20 m2        1990.0
# 3016       Prodaja        Hiša  Samostojna     140 m2        2015.0
# 3647       Prodaja  Stanovanje     2-sobno   55.65 m2        2019.0
# 6281       Prodaja  Stanovanje     2-sobno   83.74 m2        2023.0
# 167        Prodaja        Hiša  Samostojna     152 m2        1987.0
# 6385       Prodaja  Stanovanje     2-sobno   44.36 m2        2019.0
# 6207       Prodaja  Stanovanje     4-sobno  164.04 m2        2024.0
# 4925       Prodaja  Stanovanje     4-sobno   184.3 m2        1600.0
# 1036       Prodaja  Stanovanje     4-sobno   184.3 m2        1600.0
# 4999       Prodaja  Stanovanje     1-sobno    45.9 m2        2008.0
# 3608       Prodaja  Stanovanje     3-sobno  119.73 m2        2023.0
#
#              cena     prodajalec_oseba  \
# 2197    900.000 €                  NaN
# 2596  1.150.000 €         Jernej Banfi
# 5943  1.499.000 €        Gordana Kovač
# 3591  1.333.710 €                  NaN
# 6335  4.200.000 €  URBANISTIKA, d.o.o.
# 3084  1.080.000 €        Mary Markežič
# 6485  1.080.000 €        Mary Markežič
# 5052  1.012.380 €                  NaN
# 1017  3.200.000 €        BAZA AGENCIJA
# 348     245.000 €           Pia Bizjak
# 3016  1.700.000 €       Andreja Solina
# 3647    666.115 €                  NaN
# 6281    997.186 €    Nina Bračko Colja
# 167   1.800.000 €         Jana  Tertei
# 6385    523.957 €                  NaN
# 6207  1.936.920 €           Esad Čeman
# 4925  2.100.000 €          Sanja Đukić
# 1036  2.100.000 €   Polona Božič Bižal
# 4999    495.000 €         Matej Krečič
# 3608  1.290.000 €    Nina Bračko Colja
#
#                            prodajalec_agencija  \
# 2197                       Zeta, d.o.o., Piran
# 2596                      CENTURY 21 Slovenija
# 5943  ORIZONT NEPREMIČNINE, Gordana Kovač s.p.
# 3591                     Altum AE Group d.o.o.
# 6335                        Urbanistika d.o.o.
# 3084                          RUJ nepremičnine
# 6485                          RUJ nepremičnine
# 5052                     Altum AE Group d.o.o.
# 1017                      BAZA AGENCIJA d.o.o.
# 348                                KW Slovenia
# 3016                      CENTURY 21 Slovenija
# 3647                     Altum AE Group d.o.o.
# 6281                   NEXT MOVE ENERGY d.o.o.
# 167                           ABC nepremičnine
# 6385                     Altum AE Group d.o.o.
# 6207                       Stoja trade, d.o.o.
# 4925                       Stoja trade, d.o.o.
# 1036                   Polona Božič Bižal s.p.
# 4999                      CENTURY 21 Slovenija
# 3608                   NEXT MOVE ENERGY d.o.o.
#
#                                                 splosno  \
# 2197  Velikost (bruto):=60 m2|Parcela:=2907 m2|Zgraj...
# 2596  Nadstropje:=3|Št. spalnic=1|Zgrajeno:=2022|Sta...
# 5943  Velikost (neto):=100 m2|Velikost (bruto):=110 ...
# 3591  Velikost (bruto):=99.65 m2|Nadstropje:=Pritlič...
# 6335  Velikost (bruto):=315 m2|Parcela:=8001 m2|Zgra...
# 3084  Velikost (bruto):=82 m2|Parcela:=1737 m2|Št. s...
# 6485  Velikost (bruto):=82 m2|Parcela:=1737 m2|Št. s...
# 5052  Velikost (bruto):=81.91 m2|Nadstropje:=2/3|Zgr...
# 1017  Velikost (bruto):=261 m2|Parcela:=905 m2|Št. s...
# 348   Velikost (bruto):=20 m2|Nadstropje:=Pritličje/...
# 3016  Velikost (bruto):=140 m2|Parcela:=400 m2|Zgraj...
# 3647  Velikost (bruto):=55.65 m2|Nadstropje:=1/3|Zgr...
# 6281  Velikost (bruto):=83.74 m2|Nadstropje:=6/7|Št....
# 167   Velikost (bruto):=152 m2|Parcela:=3084 m2|Zgra...
# 6385  Velikost (bruto):=44.36 m2|Nadstropje:=1/3|Zgr...
# 6207  Velikost (neto):=110.61 m2|Velikost (bruto):=1...
# 4925  Velikost (bruto):=184.3 m2|Nadstropje:=2|Zgraj...
# 1036  Velikost (bruto):=184.3 m2|Nadstropje:=2|Zgraj...
# 4999  Velikost (bruto):=45.9 m2|Nadstropje:=2/2|Št. ...
# 3608  Velikost (bruto):=119.73 m2|Nadstropje:=6/7|Št...
#
#                                             znacilnosti  \
# 2197                                                NaN
# 2596  Priključki=Telefon/Kabelski priklj./Optika|Ogr...
# 5943  Ogrevanje=CK|Lega=Jug|Luksuz=Lep razgled/Bliži...
# 3591  Dodatno=Atrij/Parkirišče/Terasa|Ogrevanje=Topl...
# 6335                                                NaN
# 3084  Ogrevanje=Elektrika/Klima|Luksuz=Lep razgled/B...
# 6485  Ogrevanje=Elektrika/Klima|Luksuz=Lep razgled/B...
# 5052  Dodatno=Balkon/Parkirišče/Terasa|Ogrevanje=Top...
# 1017  Luksuz=Fitnes/Lep razgled/Bližina narave/Zelo ...
# 348   Ogrevanje=Elektrika/Klima|Lega=Zahod|Luksuz=Kl...
# 3016                  Luksuz=Bližina narave/Zelo sončno
# 3647  Dodatno=Balkon/Parkirišče|Ogrevanje=Toplotna č...
# 6281  Ogrevanje=Toplarna/Klima/Rekuperator/Talno gretje
# 167                               Dodatno=Balkon/Terasa
# 6385  Dodatno=Parkirišče|Ogrevanje=Toplotna črpalka/...
# 6207  Priključki=Optika|Ogrevanje=Toplotna črpalka/K...
# 4925                                                NaN
# 1036                                                NaN
# 4999  Ogrevanje=CK/Toplotna črpalka|Lega=SZ|Luksuz=K...
# 3608  Ogrevanje=Toplarna/Rekuperator/Talno gretje/Klima
#
#                                                    opis  \
# 2197  IZOLAOdličen panoramski razgled na morje in Iz...
# 2596  PRODAMO LUKSUZNO STANOVANJE V TOP CENTRU LJUBL...
# 5943  Piran; na odlični lokaciji, z odprtim pogledom...
# 3591  LUKSEMBURG, BASCHARAGEProstorno 3-sobno stanov...
# 6335  TRIESTE - MUGGIA - LAZZARETTOMILJE - LAZARET O...
# 3084  Samostojna hiša KolombanNa čudoviti in mirni l...
# 6485  Hiša+zazidljiva parcela KolombanNa čudoviti in...
# 5052  LUKSEMBURG, BASCHARAGESvetlo 3-sobno stanovanj...
# 1017  Prodamo izjemno vilo v Elviriji, ki predstavlj...
# 348   V Piranu na Fornačah prodamo poslovni apartma....
# 3016  Čudovita posest v NerezinahPosredujem pri prod...
# 3647  LUKSEMBURG, BASCHARAGESvetlo 2-sobno stanovanj...
# 6281  Stanovanje p.SE.06.09Predstavljamo vam sodobno...
# 167   KOPER, EKSKLUZIVNA VILAKOPER, parcela 3.084 m²...
# 6385  LUKSEMBURG, BASCHARAGENovo 2-sobno stanovanje ...
# 6207  Samo za tiste, ki si želijo privoščiti vrhunsk...
# 4925  Pozabite na pričakovano! Predstavljamo vam naj...
# 1036  NAJBOLJ AVANTGARDNO STANOVANJE V SLOVENIJINa i...
# 4999  Predstavljamo vam enosobno stanovanje v Izoli,...
# 3608  Stanovanje p.SE.06.03Predstavljamo vam moderno...
#
#                                                     url  velikost_clean  \
# 2197  https://mojikvadrati.com/nepremicnina/434910-p...           60.00
# 2596  https://mojikvadrati.com/nepremicnina/481049-p...           80.10
# 5943  https://mojikvadrati.com/nepremicnina/481504-p...          110.00
# 3591  https://mojikvadrati.com/nepremicnina/469348-p...           99.65
# 6335  https://mojikvadrati.com/nepremicnina/469436-p...          315.00
# 3084  https://mojikvadrati.com/nepremicnina/474216-p...           82.00
# 6485  https://mojikvadrati.com/nepremicnina/475190-p...           82.00
# 5052  https://mojikvadrati.com/nepremicnina/482342-p...           81.91
# 1017  https://mojikvadrati.com/nepremicnina/472347-p...          261.00
# 348   https://mojikvadrati.com/nepremicnina/445202-p...           20.00
# 3016  https://mojikvadrati.com/nepremicnina/477108-p...          140.00
# 3647  https://mojikvadrati.com/nepremicnina/482341-p...           55.65
# 6281  https://mojikvadrati.com/nepremicnina/478081-p...           83.74
# 167   https://mojikvadrati.com/nepremicnina/479306-p...          152.00
# 6385  https://mojikvadrati.com/nepremicnina/467536-p...           44.36
# 6207  https://mojikvadrati.com/nepremicnina/466438-p...          164.04
# 4925  https://mojikvadrati.com/nepremicnina/399777-p...          184.30
# 1036  https://mojikvadrati.com/nepremicnina/438664-p...          184.30
# 4999  https://mojikvadrati.com/nepremicnina/480742-p...           45.90
# 3608  https://mojikvadrati.com/nepremicnina/478080-p...          119.73
#
#       cena_clean    cena_na_m2
# 2197    900000.0  15000.000000
# 2596   1150000.0  14357.053683
# 5943   1499000.0  13627.272727
# 3591   1333710.0  13383.943803
# 6335   4200000.0  13333.333333
# 3084   1080000.0  13170.731707
# 6485   1080000.0  13170.731707
# 5052   1012380.0  12359.663045
# 1017   3200000.0  12260.536398
# 348     245000.0  12250.000000
# 3016   1700000.0  12142.857143
# 3647    666115.0  11969.721473
# 6281    997186.0  11908.120373
# 167    1800000.0  11842.105263
# 6385    523957.0  11811.474301
# 6207   1936920.0  11807.607901
# 4925   2100000.0  11394.465545
# 1036   2100000.0  11394.465545
# 4999    495000.0  10784.313725
# 3608   1290000.0  10774.242045

# %% [markdown]
# Kaj pa vse skupaj?

# %%
kvadrati_df2 = kvadrati_df.copy()
kvadrati_df2['velikost_clean'] = kvadrati_df2['velikost'].apply(get_velikost)
# hs_df['cena_clean'] = hs_df['cena'].apply(get_cena)
kvadrati_df2['cena_clean'] = kvadrati_df2.apply(lambda row: očisti_ceno(row['cena'], row['velikost']), axis=1)
kvadrati_df2['cena_na_m2'] = kvadrati_df2['cena_clean'] / kvadrati_df2['velikost_clean']
kvadrati_df2
# Out:
#         id                                          naslov   latitude  \
# 0        1  Notranjsko - kraška, Ilirska Bistrica, Hrušica  45.846179
# 1        2                         Pomurska, Murska Sobota  46.662464
# 2        3                 Podravska, Destrnik, Vintarovci  46.495602
# 3        4                  Goriška, Kanal ob Soči, Doblar  46.115738
# 4        5                       Podravska, Maribor, Pekre  46.543337
# ...    ...                                             ...        ...
# 6775  6792                                Ljubljana, Šiška  46.073720
# 6776  6793                   Ljubljana, Vič-Rudnik, Rudnik  50.444777
# 6777  6794                                            Umag  45.432359
# 6778  6795                                 Goriška, Idrija  46.002398
# 6779  6796                  Obalno - kraška, Koper, Šmarje  45.500498
#
#       longitude vrsta_prodaje             vrsta                  tip  \
# 0     14.230267       Prodaja           Parcela           Zazidljiva
# 1     16.165526       Prodaja           Parcela           Zazidljiva
# 2     15.864561       Prodaja           Parcela           Zazidljiva
# 3     13.687290       Prodaja              Hiša           Samostojna
# 4     15.592553       Prodaja              Hiša      Večstanovanjska
# ...         ...           ...               ...                  ...
# 6775  14.485868       Prodaja        Stanovanje              4-sobno
# 6776  22.244033       Prodaja        Stanovanje              4-sobno
# 6777  13.522410       Prodaja        Stanovanje              2-sobno
# 6778  14.027301       Prodaja  Poslovni prostor  Neživilska trgovina
# 6779  13.717103       Prodaja  Poslovni prostor              Pisarna
#
#        velikost  leto_gradnje       cena     prodajalec_oseba  \
# 0       4194 m2           NaN   37.000 €          Nina Hudnik
# 1       1898 m2           NaN    40 €/m2       Rajko  Šimonka
# 2        646 m2           NaN   23.500 €       Melanija Raišp
# 3      223.6 m2        1924.0  110.000 €           Jure Repše
# 4      322.6 m2        1973.0  579.000 €      Barbara Pečenik
# ...         ...           ...        ...                  ...
# 6775    93.1 m2        1983.0  398.000 €        Urška Hočevar
# 6776    97.2 m2        2020.0  470.000 €  Rojal invest d.o.o.
# 6777      65 m2        2019.0  235.000 €          Sara Ducman
# 6778  309.13 m2        1980.0  300.000 €          Marko Udovč
# 6779     130 m2        2025.0  285.595 €          Zoran Đukić
#
#             prodajalec_agencija  \
# 0      RONI NEPREMIČNINE d.o.o.
# 1     Prips nepremičnine d.o.o.
# 2          CENTURY 21 Slovenija
# 3                  RENES d.o.o.
# 4          BAZA AGENCIJA d.o.o.
# ...                         ...
# 6775                Stan d.o.o.
# 6776        Rojal invest d.o.o.
# 6777         INFINIS PROPERTIES
# 6778            REVESTUM d.o.o.
# 6779        Stoja trade, d.o.o.
#
#                                                 splosno  \
# 0                                 Šifra:=PP397815031525
# 1                                       Šifra:=P26-2022
# 2                                     Šifra:=100104-589
# 3     Parcela:=17967 m2|Zgrajeno:=1924|Ener. izk.=G|...
# 4     Velikost (bruto):=322.6 m2|Parcela:=535 m2|Št....
# ...                                                 ...
# 6775  Velikost (bruto):=93.1 m2|Zgrajeno:=1983|Adapt...
# 6776  Velikost (bruto):=97.2 m2|Nadstropje:=1|Zgraje...
# 6777  Velikost (bruto):=65 m2|Nadstropje:=Pritličje|...
# 6778  Velikost (bruto):=309.13 m2|Nadstropje:=Pritli...
# 6779  Velikost (bruto):=130 m2|Nadstropje:=Pritličje...
#
#                                             znacilnosti  \
# 0                                                   NaN
# 1                                                   NaN
# 2     Lega=Jug/Zahod|Luksuz=Lep razgled/Bližina nara...
# 3                           Dodatno=Balkon/Atrij/Terasa
# 4     Ogrevanje=Toplotna črpalka|Luksuz=Klima/Lep ra...
# ...                                                 ...
# 6775                  Dodatno=Dvigalo/Balkon/Parkirišče
# 6776                             Dodatno=Balkon/Dvigalo
# 6777  Ogrevanje=Toplotna črpalka/Talno gretje|Luksuz...
# 6778                         Ogrevanje=Toplotna črpalka
# 6779  Luksuz=Klima/Lep razgled/Bližina narave/Zelo s...
#
#                                                    opis  \
# 0     Iščete primerno zemljišče za gradnjo ali inves...
# 1     Nedaleč od trgovskega središča prodamo zemljiš...
# 2     ZEMLJIŠČE V VINTAROVCIH, DESTRNIKProdamo zemlj...
# 3     DOBLARSamostojna stanovanjska hiša velikosti 2...
# 4     Na odlični in mirni lokaciji v Pekrah prodamo ...
# ...                                                 ...
# 6775  LJ. ŠIŠKA, DRAVLJE, BLIŽINA ZELENIH POVRŠINide...
# 6776  Ljubljana, Peruzzijeva ulica –Vila Bober, stan...
# 6777  Prodamo čudovito 2-sobno stanovanje v luksuzne...
# 6778  Poslovni prostor - prodajalna v IdrijiPoslovni...
# 6779  Iščete idealen poslovni prostor na vrhunski lo...
#
#                                                     url  velikost_clean  \
# 0     https://mojikvadrati.com/nepremicnina/467410-p...         4194.00
# 1     https://mojikvadrati.com/nepremicnina/373458-p...         1898.00
# 2     https://mojikvadrati.com/nepremicnina/453310-p...          646.00
# 3     https://mojikvadrati.com/nepremicnina/424445-p...          223.60
# 4     https://mojikvadrati.com/nepremicnina/469054-p...          322.60
# ...                                                 ...             ...
# 6775  https://mojikvadrati.com/nepremicnina/482910-p...           93.10
# 6776  https://mojikvadrati.com/nepremicnina/482529-p...           97.20
# 6777  https://mojikvadrati.com/nepremicnina/473926-p...           65.00
# 6778  https://mojikvadrati.com/nepremicnina/472166-p...          309.13
# 6779  https://mojikvadrati.com/nepremicnina/479853-p...          130.00
#
#       cena_clean   cena_na_m2
# 0        37000.0     8.822127
# 1            NaN          NaN
# 2        23500.0    36.377709
# 3       110000.0   491.949911
# 4       579000.0  1794.792312
# ...          ...          ...
# 6775    398000.0  4274.973147
# 6776    470000.0  4835.390947
# 6777    235000.0  3615.384615
# 6778    300000.0   970.465500
# 6779    285595.0  2196.884615
#
# [6780 rows x 19 columns]

# %%
kvadrati_df2.dropna().sort_values("cena_na_m2")
# Out:
#         id                                    naslov   latitude  longitude  \
# 1629  1631  Pomurska, Križevci, Iljaševci,  BLIZU AC  46.575240  16.128631
# 1609  1611                   Podravska, Ruše, Center  31.795281 -94.180358
# 3514  3517                Gorenjska, Jesenice, Lipce  53.734695  15.674436
# 6613  6628   Podravska, Hoče - Slivnica, Orehova vas  46.473085  15.663466
# 4353  4358                   Savinjska, Tabor, Kapla  46.104875  14.909357
# ...    ...                                       ...        ...        ...
# 2596  2598                         Ljubljana, Center  31.795281 -94.180358
# 6064  6076                Ljubljana, Vič-Rudnik, Vič  46.044136  14.488113
# 6156  6168                                      Nica  43.700936   7.268391
# 2217  2219             Ljubljana, Vič-Rudnik, Rudnik  50.444777  22.244033
# 6408  6423                Savinjska, Rogaška Slatina  46.232990  15.638437
#
#      vrsta_prodaje             vrsta                  tip   velikost  \
# 1629       Prodaja           Parcela           Zazidljiva    2190 m2
# 1609       Prodaja           Parcela           Zazidljiva     523 m2
# 3514       Prodaja           Parcela           Zazidljiva   25545 m2
# 6613       Prodaja           Parcela           Zazidljiva    5000 m2
# 4353       Prodaja           Parcela           Zazidljiva    1586 m2
# ...            ...               ...                  ...        ...
# 2596       Prodaja        Stanovanje              2-sobno    80.1 m2
# 6064       Prodaja  Poslovni prostor  Neživilska trgovina    55.8 m2
# 6156       Prodaja              Hiša           Samostojna     643 m2
# 2217       Prodaja           Parcela           Zazidljiva   3.188 m2
# 6408       Prodaja  Poslovni prostor                Hotel  12.018 m2
#
#       leto_gradnje          cena    prodajalec_oseba     prodajalec_agencija  \
# 1629        1925.0      55.000 €        Nejc Rokavec          LA REAL d.o.o.
# 1609        2024.0      20.900 €     Amadej Miklošič    CENTURY 21 Slovenija
# 3514        2014.0   1.280.000 €  Makler Bled d.o.o.      Makler Bled d.o.o.
# 6613        1942.0     395.000 €       Aljaž Berginc            24nep d.o.o.
# 4353        1952.0     155.000 €          Nika Glame  Ljubljana nepremicnine
# ...            ...           ...                 ...                     ...
# 2596        2022.0   1.150.000 €        Jernej Banfi    CENTURY 21 Slovenija
# 6064        1981.0     900.000 €        Janez Dragar     Stoja trade, d.o.o.
# 6156        1911.0  47.000.000 €       BAZA AGENCIJA    BAZA AGENCIJA d.o.o.
# 2217        1875.0   1.562.120 €        Janez Dragar     Stoja trade, d.o.o.
# 6408        1973.0  26.500.000 €          Robi Slana            24nep d.o.o.
#
#                                                 splosno  \
# 1629  Velikost (neto):=144.6 m2|Velikost (bruto):=19...
# 1609                   Zgrajeno:=2024|Šifra:=100103-241
# 3514  Velikost (bruto):=145 m2|Št. spalnic=2|Zgrajen...
# 6613  Zgrajeno:=1942|Ener. izk.=Ni podatka|Šifra:=03...
# 4353  Velikost (bruto):=124.5 m2|Št. spalnic=2|Zgraj...
# ...                                                 ...
# 2596  Nadstropje:=3|Št. spalnic=1|Zgrajeno:=2022|Sta...
# 6064  Nadstropje:=Pritličje/1|Parcela:=973 m2|Zgraje...
# 6156  Velikost (bruto):=643 m2|Parcela:=16500 m2|Št....
# 2217  Zgrajeno:=1875|Ener. izk.=Ni podatka|Šifra:=PZ...
# 6408  Velikost (bruto):=12.018 m2|Parcela:=10.347 m2...
#
#                                             znacilnosti  \
# 1629  Priključki=Telefon/Kabelski priklj.|Ogrevanje=...
# 1609                              Luksuz=Bližina narave
# 3514      Luksuz=Zelo sončno/Lep razgled/Bližina narave
# 6613                Priključki=Telefon/Kabelski priklj.
# 4353  Ogrevanje=Biomasa|Luksuz=Lep razgled/Bližina n...
# ...                                                 ...
# 2596  Priključki=Telefon/Kabelski priklj./Optika|Ogr...
# 6064  Priključki=Optika/Telefon|Ogrevanje=Klima|Lega...
# 6156  Luksuz=Fitnes/Bazen/Lep razgled/Bližina narave...
# 2217                         Dodatno=Pokrito parkirišče
# 6408  Priključki=Kabelski priklj./Telefon|Ogrevanje=...
#
#                                                    opis  \
# 1629  ILJAŠEVCI, BLIZU ACZEMLJIŠČE Z GRADBENIM DOVOL...
# 1609  PRODAMO ZAZIDLJIVO PARCELO, locirano v centru ...
# 3514  Lipce pri Blejski Dobravi,  avtokamp  Perun  o...
# 6613  Velik potencial za gradnjoVELIKO STAVBNO ZEMLJ...
# 4353  Na čudoviti in mirni lokaciji v naselju Kapla ...
# ...                                                 ...
# 2596  PRODAMO LUKSUZNO STANOVANJE V TOP CENTRU LJUBL...
# 6064  Odlična vidna lokacija!Parcela z objektom v po...
# 6156  Na francoski rivieri, v obmorskem mestecu v bl...
# 2217  Mirna lokacija!Zazidljivo zemljiše; Rudnik!Na ...
# 6408  Izjemna in edinstvena lokacijaHOTEL DONAT  - v...
#
#                                                     url  velikost_clean  \
# 1629  https://mojikvadrati.com/nepremicnina/481128-p...        2190.000
# 1609  https://mojikvadrati.com/nepremicnina/451636-p...         523.000
# 3514  https://mojikvadrati.com/nepremicnina/444464-p...       25545.000
# 6613  https://mojikvadrati.com/nepremicnina/482068-p...        5000.000
# 4353  https://mojikvadrati.com/nepremicnina/475913-p...        1586.000
# ...                                                 ...             ...
# 2596  https://mojikvadrati.com/nepremicnina/481049-p...          80.100
# 6064  https://mojikvadrati.com/nepremicnina/444409-p...          55.800
# 6156  https://mojikvadrati.com/nepremicnina/450274-p...         643.000
# 2217  https://mojikvadrati.com/nepremicnina/393944-p...           3.188
# 6408  https://mojikvadrati.com/nepremicnina/466321-p...          12.018
#
#       cena_clean    cena_na_m2
# 1629     55000.0  2.511416e+01
# 1609     20900.0  3.996176e+01
# 3514   1280000.0  5.010765e+01
# 6613    395000.0  7.900000e+01
# 4353    155000.0  9.773014e+01
# ...          ...           ...
# 2596   1150000.0  1.435705e+04
# 6064    900000.0  1.612903e+04
# 6156  47000000.0  7.309487e+04
# 2217   1562120.0  4.900000e+05
# 6408  26500000.0  2.205026e+06
#
# [3414 rows x 19 columns]

# %% [markdown]
# Parcele so dosti poceni. Najdražji vikendi v tujini. Načeloma so pri velikosti decimalne pike, ampak potem nad 1000m2 so pike za ločevanje tisočic.

# %%
kvadrati_df3 = kvadrati_df2[kvadrati_df2["cena_na_m2"] <= 15000]
plt.figure()
plt.hist(kvadrati_df3["cena_na_m2"], bins="sqrt")
plt.legend();

# %% [markdown]
# Parcele so res poceni.

# %%
kvadrati_df3 = kvadrati_df2[(kvadrati_df2["cena_na_m2"] <= 20000) & (kvadrati_df2["cena_na_m2"] > 500)]
plt.figure()
plt.hist(kvadrati_df3["cena_na_m2"], bins="sqrt")
plt.legend();

kvadrati_df3.sort_values("cena_na_m2")
# Out:
#         id                                             naslov   latitude  \
# 3789  3792  Ljubljana okolica, Domžale, Rodica,  TOP LOKACIJA  46.227750
# 412    413                 Ljubljana okolica, Domžale, Rodica  46.227750
# 3509  3512                     Jugovzhodna Slovenija, Kočevje  45.643027
# 4610  4615              Ljubljana okolica, Šmartno pri Litiji  46.044070
# 4507  4512                  Spodnjeposavska, Sevnica,  CENTER  31.795281
# ...    ...                                                ...        ...
# 2596  2598                                  Ljubljana, Center  31.795281
# 2197  2199                             Obalno - kraška, Izola  45.539894
# 6064  6076                         Ljubljana, Vič-Rudnik, Vič  46.044136
# 5282  5289          Hrvaška, Biograd na Moru, BIOGRAD NA MORU  43.937715
# 658    660               Podravska, Trnovska vas, Bišečki Vrh  46.517536
#
#       longitude vrsta_prodaje              vrsta                  tip  \
# 3789  13.865180       Prodaja            Parcela           Zazidljiva
# 412   13.865180       Prodaja            Parcela           Zazidljiva
# 3509  14.855270       Prodaja               Hiša           Samostojna
# 4610  14.843123       Prodaja               Hiša           Samostojna
# 4507 -94.180358       Prodaja         Stanovanje         5+ več sobno
# ...         ...           ...                ...                  ...
# 2596 -94.180358       Prodaja         Stanovanje              2-sobno
# 2197  13.659390       Prodaja               Hiša           Samostojna
# 6064  14.488113       Prodaja   Poslovni prostor  Neživilska trgovina
# 5282  15.447764       Prodaja  Počitniški objekt               Vikend
# 658   15.875348       Prodaja            Parcela           Zazidljiva
#
#       velikost  leto_gradnje         cena     prodajalec_oseba  \
# 3789   1976 m2           NaN    990.000 €  Mateja Funtek Derča
# 412    1976 m2           NaN    990.000 €         LUKA ŠKOVRLJ
# 3509    736 m2        1900.0    370.000 €         Petra Lunder
# 4610  356.5 m2        1670.0    180.000 €        Karmen Tertei
# 4507  375.4 m2        1922.0    190.000 €                  NaN
# ...        ...           ...          ...                  ...
# 2596   80.1 m2        2022.0  1.150.000 €         Jernej Banfi
# 2197     60 m2        1900.0    900.000 €                  NaN
# 6064   55.8 m2        1981.0    900.000 €         Janez Dragar
# 5282     41 m2        2000.0    698.000 €       Bogdan Capuder
# 658   2.802 m2           NaN     47.900 €      Barbara Pečenik
#
#                            prodajalec_agencija  \
# 3789            Loox, Mateja Funtek Derča s.p.
# 412                   Mesto nepremičnin d.o.o.
# 3509                               KW Slovenia
# 4610                          ABC nepremičnine
# 4507  FLEKS nepremičnine, Gregor Jarkovič s.p.
# ...                                        ...
# 2596                      CENTURY 21 Slovenija
# 2197                       Zeta, d.o.o., Piran
# 6064                       Stoja trade, d.o.o.
# 5282                            BCAKTIV d.o.o.
# 658                       BAZA AGENCIJA d.o.o.
#
#                                                 splosno  \
# 3789                                                NaN
# 412                                        Šifra:=P7838
# 3509  Velikost (neto):=412 m2|Velikost (bruto):=736 ...
# 4610  Velikost (bruto):=356.5 m2|Parcela:=1385 m2|Zg...
# 4507  Velikost (bruto):=375.4 m2|Zgrajeno:=1922|Adap...
# ...                                                 ...
# 2596  Nadstropje:=3|Št. spalnic=1|Zgrajeno:=2022|Sta...
# 2197  Velikost (bruto):=60 m2|Parcela:=2907 m2|Zgraj...
# 6064  Nadstropje:=Pritličje/1|Parcela:=973 m2|Zgraje...
# 5282       Parcela:=1978 m2|Zgrajeno:=2000|Šifra:=POP66
# 658                                Šifra:=PP13461225439
#
#                                             znacilnosti  \
# 3789                                                NaN
# 412                                 Priključki=Plinovod
# 3509                                                NaN
# 4610                                                NaN
# 4507           Dodatno=Balkon/Parkirišče|Ogrevanje=Drva
# ...                                                 ...
# 2596  Priključki=Telefon/Kabelski priklj./Optika|Ogr...
# 2197                                                NaN
# 6064  Priključki=Optika/Telefon|Ogrevanje=Klima|Lega...
# 5282                                                NaN
# 658                                                 NaN
#
#                                                    opis  \
# 3789  RODICA, TOP LOKACIJADOMŽALE - RODICA - Izjemna...
# 412   Parcela v neposredni bližini Domžal ijemna pri...
# 3509  Vila s parcelo za investicijoPredstavljamo vam...
# 4610  ŠMARTNO PRI LITIJIŠmartno pri Litiji, prodamo ...
# 4507  SEVNICA, CENTERV centru Sevnice prodamo večje ...
# ...                                                 ...
# 2596  PRODAMO LUKSUZNO STANOVANJE V TOP CENTRU LJUBL...
# 2197  IZOLAOdličen panoramski razgled na morje in Iz...
# 6064  Odlična vidna lokacija!Parcela z objektom v po...
# 5282  BIOGRAD NA MORUZemljišče, ki meri 1.978 m², je...
# 658   V slikovitem naselju Bišečki Vrh, ki se nahaja...
#
#                                                     url  velikost_clean  \
# 3789  https://mojikvadrati.com/nepremicnina/444085-p...        1976.000
# 412   https://mojikvadrati.com/nepremicnina/440726-p...        1976.000
# 3509  https://mojikvadrati.com/nepremicnina/436175-p...         736.000
# 4610  https://mojikvadrati.com/nepremicnina/469838-p...         356.500
# 4507  https://mojikvadrati.com/nepremicnina/433028-p...         375.400
# ...                                                 ...             ...
# 2596  https://mojikvadrati.com/nepremicnina/481049-p...          80.100
# 2197  https://mojikvadrati.com/nepremicnina/434910-p...          60.000
# 6064  https://mojikvadrati.com/nepremicnina/444409-p...          55.800
# 5282  https://mojikvadrati.com/nepremicnina/418209-p...          41.000
# 658   https://mojikvadrati.com/nepremicnina/467103-p...           2.802
#
#       cena_clean    cena_na_m2
# 3789    990000.0    501.012146
# 412     990000.0    501.012146
# 3509    370000.0    502.717391
# 4610    180000.0    504.908836
# 4507    190000.0    506.126798
# ...          ...           ...
# 2596   1150000.0  14357.053683
# 2197    900000.0  15000.000000
# 6064    900000.0  16129.032258
# 5282    698000.0  17024.390244
# 658      47900.0  17094.932191
#
# [4863 rows x 19 columns]

# %% [markdown]
# Cene celih nepremičnin (stanovnja in hiše)

# %%
plt.figure()
plt.hist(hs_df["cena_clean"], bins="sqrt");

# %% [markdown]
# Zoom in na pod 4 mil:

# %%
hs_df2 = hs_df[(hs_df["cena_clean"].notnull()) & (hs_df["cena_clean"] < 4 * 1e6)]
plt.figure()
plt.hist(hs_df2["cena_clean"], bins="sqrt");

# %% [markdown]
# Spet Beta:

# %%
cena_cela = hs_df2["cena_clean"]
pars_b2 = beta.fit(cena_cela)
print(pars_b2)

xb = np.linspace(cena_cela.min(), cena_cela.max(), 1000)
B_fit2 = [beta.pdf(x, *pars_b2) for x in xb]

plt.figure()
plt.hist(cena_cela, bins="sqrt", density=True)
# plt.hist(leto_normalized)
plt.plot(xb, B_fit2, label="Beta porazdelitev", linewidth=2.0)
plt.legend();
# Out:
# (np.float64(1.8747788028288461), np.float64(313703281.83495706), np.float64(-42.03988592117152), np.float64(77237281588323.53))
